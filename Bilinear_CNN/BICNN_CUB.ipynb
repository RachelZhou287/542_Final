# %%
import os
print(os.getcwd())
os.chdir("/root/stat542")
import torch, gc
gc.collect()
torch.cuda.empty_cache()
# Out:
# /root/stat542

# %% [markdown]
# * Slightly Overfitting but stable

# %%
# ============================================================
# Bilinear CNN (Full Fine-Tuning, No AMP)
# Dataset: CUB-200-2011
# ============================================================
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models, transforms
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt

# ============================================================
# Dataset
# ============================================================
class CUBDataset(torch.utils.data.Dataset):
    def __init__(self, root, train=True, transform=None):
        self.root = root
        self.transform = transform
        img_txt = os.path.join(root, "images.txt")
        label_txt = os.path.join(root, "image_class_labels.txt")
        split_txt = os.path.join(root, "train_test_split.txt")

        with open(img_txt) as f:
            lines = [line.strip() for line in f]
        with open(label_txt) as f:
            labels = [int(l.split()[1]) - 1 for l in f]
        with open(split_txt) as f:
            splits = [int(l.split()[1]) for l in f]

        self.samples = []
        for i, line in enumerate(lines):
            if (train and splits[i] == 1) or (not train and splits[i] == 0):
                img_path = os.path.join(root, "images", line.split()[1])
                self.samples.append((img_path, labels[i]))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        img = Image.open(path).convert("RGB")
        if self.transform:
            img = self.transform(img)
        return img, label


# ============================================================
# Bilinear CNN Model
# ============================================================
class BilinearCNN(nn.Module):
    def __init__(self, num_classes=200, dropout_p=0.25):
        super().__init__()
        backbone = models.vgg16_bn(weights=models.VGG16_BN_Weights.IMAGENET1K_V1) #pre-trained weights
        self.features = nn.Sequential(*list(backbone.features.children())[:-1])
        self.num_features = 512
        self.fc = nn.Linear(self.num_features * self.num_features, num_classes)
        nn.init.kaiming_uniform_(self.fc.weight, nonlinearity="linear")
        nn.init.constant_(self.fc.bias, 0.0)
        self.dropout_p = dropout_p

    def forward(self, x):
        x = self.features(x)               # (B, 512, H, W)
        B, C, H, W = x.size()
        x = x + 1e-5                       # small bias to prevent zero maps
        x = x.view(B, C, H * W)
        x = torch.bmm(x, x.transpose(1, 2)) / (H * W)
        x = x.view(B, -1)
        x = torch.sign(x) * torch.sqrt(torch.abs(x) + 1e-10)
        x = F.normalize(x, dim=1)
        x = F.dropout(x, p=self.dropout_p, training=self.training)
        return self.fc(x)


# ============================================================
# Training / Evaluation
# ============================================================
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss, total_correct, total_samples = 0, 0, 0

    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * labels.size(0)
        preds = logits.argmax(1)
        total_correct += (preds == labels).sum().item()
        total_samples += labels.size(0)

    return total_loss / total_samples, total_correct / total_samples


@torch.no_grad()
def test(model, loader, criterion, device):
    model.eval()
    total_loss, total_correct, total_samples = 0, 0, 0
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        logits = model(imgs)
        loss = criterion(logits, labels)
        total_loss += loss.item() * labels.size(0)
        preds = logits.argmax(1)
        total_correct += (preds == labels).sum().item()
        total_samples += labels.size(0)
    return total_loss / total_samples, total_correct / total_samples


# ============================================================
# Main Training Pipeline
# ============================================================
if __name__ == "__main__":
    data_root = "data/CUB_200_2011"

    # --- Transforms ---
    train_transform = transforms.Compose([
    transforms.RandomResizedCrop(448, scale=(0.75, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.3, 0.3, 0.3, 0.2),
    transforms.RandomRotation(20),
    transforms.RandomPerspective(distortion_scale=0.2, p=0.3),
    transforms.RandomGrayscale(p=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])
    test_transform = transforms.Compose([
    transforms.Resize(512),
    transforms.CenterCrop(448),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

    # --- Datasets ---
    train_data = CUBDataset(data_root, train=True, transform=train_transform)
    test_data = CUBDataset(data_root, train=False, transform=test_transform)
    train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=20, pin_memory=True)
    test_loader = DataLoader(test_data, batch_size=16, shuffle=False, num_workers=20, pin_memory=True)
    print(f"Loaded {len(train_data)} training and {len(test_data)} testing images.")

    # --- Model & Setup ---
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = BilinearCNN(num_classes=200).to(device)
    criterion = nn.CrossEntropyLoss()

    # --- Optimizer ---
    optimizer = torch.optim.SGD([
    {"params": model.features[:10].parameters(), "lr": 5e-4},
    {"params": model.features[10:20].parameters(), "lr": 1e-3},
    {"params": model.features[20:].parameters(), "lr": 2e-3},
    {"params": model.fc.parameters(), "lr": 1e-2},
], momentum=0.9, weight_decay=1e-3)

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200, eta_min=1e-6)

    # --- Training ---
    print("=== Train ===")
    best_acc = 0.0
    loss_hist, acc_hist = [], []

    for epoch in range(200):
        tr_loss, tr_acc = train(model, train_loader, optimizer, criterion, device)
        te_loss, te_acc = test(model, test_loader, criterion, device)
        scheduler.step()

        print(f"[Epoch {epoch+1:02d}] Loss={tr_loss:.4f} | Train={tr_acc*100:.2f}% | Test={te_acc*100:.2f}%")
        loss_hist.append(tr_loss)
        acc_hist.append(te_acc)

        if te_acc > best_acc:
            best_acc = te_acc
            torch.save(model.state_dict(), "best_bcnn_fullfloat.pt")

   # --- Visualization ---
    plt.figure(figsize=(6, 4))
    plt.subplot(1,2,1)
    plt.plot(loss_hist, label="Train Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")

    plt.subplot(1,2,2)
    plt.plot(acc_hist, label="Test Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Test Accuracy")
    plt.title(f"Bilinear CNN Fine-Tuning (Full FP32) | Best Test Acc = {best_acc*100:.2f}%")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Loaded 5994 training and 5794 testing images.
# === Train ===
# [Epoch 01] Loss=5.2999 | Train=0.37% | Test=9.70%
# [Epoch 02] Loss=5.2909 | Train=1.74% | Test=18.42%
# [Epoch 03] Loss=5.2764 | Train=5.76% | Test=34.93%
# [Epoch 04] Loss=5.2531 | Train=15.40% | Test=37.28%
# [Epoch 05] Loss=5.2198 | Train=21.55% | Test=36.45%
# [Epoch 06] Loss=5.1783 | Train=25.03% | Test=35.02%
# [Epoch 07] Loss=5.1313 | Train=25.54% | Test=31.19%
# [Epoch 08] Loss=5.0800 | Train=24.92% | Test=31.29%
# [Epoch 182] Loss=2.4923 | Train=86.90% | Test=63.17%
# [Epoch 183] Loss=2.4917 | Train=86.97% | Test=63.29%
# [Epoch 184] Loss=2.4916 | Train=87.07% | Test=62.84%
# [Epoch 185] Loss=2.4927 | Train=87.14% | Test=62.82%
# [Epoch 186] Loss=2.4901 | Train=87.17% | Test=63.17%
# [Epoch 187] Loss=2.4904 | Train=86.87% | Test=63.19%
# [Epoch 188] Loss=2.4897 | Train=87.40% | Test=63.39%
# [Epoch 189] Loss=2.4922 | Train=86.49% | Test=63.19%
# [Epoch 190] Loss=2.4909 | Train=86.90% | Test=63.17%
# [Epoch 191] Loss=2.4912 | Train=86.84% | Test=63.15%
# [Epoch 192] Loss=2.4912 | Train=86.77% | Test=63.19%
# [Epoch 193] Loss=2.4883 | Train=87.14% | Test=63.07%
# [Epoch 194] Loss=2.4906 | Train=86.97% | Test=63.19%
# [Epoch 195] Loss=2.4910 | Train=86.90% | Test=63.19%
# [Epoch 196] Loss=2.4919 | Train=86.55% | Test=63.29%
# [Epoch 197] Loss=2.4932 | Train=87.29% | Test=63.17%
# [Epoch 198] Loss=2.4906 | Train=87.10% | Test=63.20%
# [Epoch 199] Loss=2.4891 | Train=87.12% | Test=63.19%
# [Epoch 200] Loss=2.4935 | Train=87.07% | Test=63.13%

# %% [markdown]
# * Enable Learning Rate Switch

# %%
# ============================================================
# Bilinear CNN (Full Fine-Tuning, Two-Phase LR Schedule)
# Dataset: CUB-200-2011
# ============================================================
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models, transforms
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt

# ============================================================
# Dataset
# ============================================================
class CUBDataset(torch.utils.data.Dataset):
    def __init__(self, root, train=True, transform=None):
        self.root = root
        self.transform = transform
        img_txt = os.path.join(root, "images.txt")
        label_txt = os.path.join(root, "image_class_labels.txt")
        split_txt = os.path.join(root, "train_test_split.txt")

        with open(img_txt) as f:
            lines = [line.strip() for line in f]
        with open(label_txt) as f:
            labels = [int(l.split()[1]) - 1 for l in f]
        with open(split_txt) as f:
            splits = [int(l.split()[1]) for l in f]

        self.samples = []
        for i, line in enumerate(lines):
            if (train and splits[i] == 1) or (not train and splits[i] == 0):
                img_path = os.path.join(root, "images", line.split()[1])
                self.samples.append((img_path, labels[i]))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        img = Image.open(path).convert("RGB")
        if self.transform:
            img = self.transform(img)
        return img, label


# ============================================================
# Bilinear CNN Model
# ============================================================
class BilinearCNN(nn.Module):
    def __init__(self, num_classes=200, dropout_p=0.30):
        super().__init__()
        backbone = models.vgg16_bn(weights=models.VGG16_BN_Weights.IMAGENET1K_V1)
        self.features = nn.Sequential(*list(backbone.features.children())[:-1])
        self.num_features = 512
        self.fc = nn.Linear(self.num_features * self.num_features, num_classes)
        nn.init.kaiming_uniform_(self.fc.weight, nonlinearity="linear")
        nn.init.constant_(self.fc.bias, 0.0)
        self.dropout_p = dropout_p

    def forward(self, x):
        x = self.features(x)               # (B, 512, H, W)
        B, C, H, W = x.size()
        x = x + 1e-5                       # avoid zeros
        x = x.view(B, C, H * W)
        x = torch.bmm(x, x.transpose(1, 2)) / (H * W)
        x = x.view(B, -1)
        x = torch.sign(x) * torch.sqrt(torch.abs(x) + 1e-10)
        x = F.normalize(x, dim=1)
        x = F.dropout(x, p=self.dropout_p, training=self.training)
        return self.fc(x)


# ============================================================
# Train / Eval
# ============================================================
def train(model, loader, optimizer, criterion, device):
    model.train()
    total_loss, total_correct, total_samples = 0, 0, 0
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * labels.size(0)
        preds = logits.argmax(1)
        total_correct += (preds == labels).sum().item()
        total_samples += labels.size(0)
    return total_loss / total_samples, total_correct / total_samples


@torch.no_grad()
def test(model, loader, criterion, device):
    model.eval()
    total_loss, total_correct, total_samples = 0, 0, 0
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        logits = model(imgs)
        loss = criterion(logits, labels)
        total_loss += loss.item() * labels.size(0)
        preds = logits.argmax(1)
        total_correct += (preds == labels).sum().item()
        total_samples += labels.size(0)
    return total_loss / total_samples, total_correct / total_samples


# ============================================================
# Main
# ============================================================
if __name__ == "__main__":
    data_root = "data/CUB_200_2011"

    train_transform = transforms.Compose([
        transforms.RandomResizedCrop(448, scale=(0.75, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(0.3, 0.3, 0.3, 0.2),
        transforms.RandomRotation(20),
        transforms.RandomPerspective(distortion_scale=0.2, p=0.3),
        transforms.RandomGrayscale(p=0.1),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ])

    test_transform = transforms.Compose([
        transforms.Resize(512),
        transforms.CenterCrop(448),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ])

    train_data = CUBDataset(data_root, train=True, transform=train_transform)
    test_data = CUBDataset(data_root, train=False, transform=test_transform)
    train_loader = DataLoader(train_data, batch_size=16, shuffle=True, num_workers=20, pin_memory=True)
    test_loader = DataLoader(test_data, batch_size=16, shuffle=False, num_workers=20, pin_memory=True)
    print(f"Loaded {len(train_data)} training and {len(test_data)} testing images.")

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = BilinearCNN(num_classes=200).to(device)
    criterion = nn.CrossEntropyLoss()

    # --- Initial (High LR) Optimizer ---
    optimizer = torch.optim.SGD([
    {"params": model.features[:10].parameters(), "lr": 5e-4},
    {"params": model.features[10:20].parameters(), "lr": 1e-3},
    {"params": model.features[20:].parameters(), "lr": 2e-3},
    {"params": model.fc.parameters(), "lr": 1e-2},
], momentum=0.9, weight_decay=1e-3)

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=1e-6)

    # --- Training ---
    print("=== Two-Phase Training ===")
    best_acc = 0.0
    te_acc_hist,tr_loss_hist,te_loss_hist,tr_acc_hist = [], [],[],[]

    for epoch in range(250):
        # === LR switch after epoch 100 ===
        if epoch == 100:
            print("\n>>> 2nd Stage Start <<<\n")
            optimizer = torch.optim.SGD([
                {"params": model.features[:10].parameters(), "lr": 5e-5},
                {"params": model.features[10:20].parameters(), "lr": 1e-4},
                {"params": model.features[20:].parameters(), "lr": 2e-4},
                {"params": model.fc.parameters(), "lr": 1e-3},
            ], momentum=0.9, weight_decay=1e-3)
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=150, eta_min=1e-6)

        tr_loss, tr_acc = train(model, train_loader, optimizer, criterion, device)
        te_loss, te_acc = test(model, test_loader, criterion, device)
        scheduler.step()

        print(f"[Epoch {epoch+1:03d}] Loss(train)={tr_loss:.4f} | Train={tr_acc*100:.2f}% | Test={te_acc*100:.2f}%|| Loss(test)={te_loss:.4f}")
        tr_loss_hist.append(tr_loss)
        te_loss_hist.append(te_loss)
        te_acc_hist.append(te_acc)
        tr_acc_hist.append(tr_acc)

        if te_acc > best_acc:
            best_acc = te_acc
            torch.save(model.state_dict(), "best_bcnn_two_phase.pt")

    # --- Plot ---
    plt.figure(figsize=(6, 4))
    plt.subplot(1,2,1)
    plt.plot(loss_hist, label="Train Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")

    plt.subplot(1,2,2)
    plt.plot(acc_hist, label="Test Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Test Accuracy")
    plt.title(f"Bilinear CNN Fine-Tuning (Two-Phase) | Best Test Acc = {best_acc*100:.2f}%")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Loaded 5994 training and 5794 testing images.
# === Two-Phase Training ===
# [Epoch 001] Loss(train)=5.3000 | Train=0.32% | Test=10.72%|| Loss(test)=5.2906
# [Epoch 002] Loss(train)=5.2907 | Train=1.79% | Test=16.62%|| Loss(test)=5.2788
# [Epoch 003] Loss(train)=5.2756 | Train=5.99% | Test=29.60%|| Loss(test)=5.2597
# [Epoch 004] Loss(train)=5.2520 | Train=12.41% | Test=33.79%|| Loss(test)=5.2302
# [Epoch 005] Loss(train)=5.2183 | Train=19.54% | Test=37.85%|| Loss(test)=5.1903
# [Epoch 006] Loss(train)=5.1768 | Train=23.82% | Test=33.26%|| Loss(test)=5.1443
# [Epoch 007] Loss(train)=5.1285 | Train=24.74% | Test=31.57%|| Loss(test)=5.0925
# [Epoch 008] Loss(train)=5.0779 | Train=24.51% | Test=30.50%|| Loss(test)=5.0394
# [Epoch 009] Loss(train)=5.0239 | Train=26.21% | Test=30.20%|| Loss(test)=4.9851
# [Epoch 010] Loss(train)=4.9705 | Train=25.86% | Test=29.57%|| Loss(test)=4.9323
# [Epoch 011] Loss(train)=4.9169 | Train=27.38% | Test=30.32%|| Loss(test)=4.8768
# [Epoch 012] Loss(train)=4.8632 | Train=27.83% | Test=30.24%|| Loss(test)=4.8252
# [Epoch 013] Loss(train)=4.8098 | Train=28.81% | Test=30.81%|| Loss(test)=4.7727
# [Epoch 014] Loss(train)=4.7560 | Train=30.11% | Test=30.15%|| Loss(test)=4.7255
# [Epoch 015] Loss(train)=4.7032 | Train=30.63% | Test=30.65%|| Loss(test)=4.6741
# [Epoch 016] Loss(train)=4.6554 | Train=30.88% | Test=30.89%|| Loss(test)=4.6317
# [Epoch 017] Loss(train)=4.6063 | Train=30.78% | Test=32.71%|| Loss(test)=4.5783
# [Epoch 018] Loss(train)=4.5582 | Train=31.90% | Test=32.41%|| Loss(test)=4.5400
# [Epoch 019] Loss(train)=4.5146 | Train=33.33% | Test=32.02%|| Loss(test)=4.4953
# [Epoch 020] Loss(train)=4.4684 | Train=33.60% | Test=33.36%|| Loss(test)=4.4538
# [Epoch 021] Loss(train)=4.4250 | Train=34.67% | Test=33.05%|| Loss(test)=4.4185
# [Epoch 022] Loss(train)=4.3807 | Train=36.92% | Test=34.09%|| Loss(test)=4.3798
# [Epoch 023] Loss(train)=4.3368 | Train=36.70% | Test=37.07%|| Loss(test)=4.3364
# [Epoch 024] Loss(train)=4.2994 | Train=37.84% | Test=36.23%|| Loss(test)=4.3040
# [Epoch 025] Loss(train)=4.2603 | Train=37.50% | Test=37.54%|| Loss(test)=4.2644
# [Epoch 026] Loss(train)=4.2173 | Train=39.76% | Test=38.04%|| Loss(test)=4.2369
# [Epoch 027] Loss(train)=4.1816 | Train=40.07% | Test=38.06%|| Loss(test)=4.1998
# [Epoch 028] Loss(train)=4.1449 | Train=41.11% | Test=38.52%|| Loss(test)=4.1730
# [Epoch 029] Loss(train)=4.1111 | Train=40.94% | Test=38.61%|| Loss(test)=4.1467
# [Epoch 030] Loss(train)=4.0796 | Train=42.54% | Test=41.56%|| Loss(test)=4.1061
# [Epoch 031] Loss(train)=4.0430 | Train=43.29% | Test=39.82%|| Loss(test)=4.0841
# [Epoch 032] Loss(train)=4.0130 | Train=44.18% | Test=40.59%|| Loss(test)=4.0618
# [Epoch 033] Loss(train)=3.9823 | Train=44.91% | Test=42.34%|| Loss(test)=4.0266
# [Epoch 034] Loss(train)=3.9505 | Train=45.15% | Test=41.96%|| Loss(test)=4.0041
# [Epoch 035] Loss(train)=3.9191 | Train=46.31% | Test=41.44%|| Loss(test)=3.9811
# [Epoch 036] Loss(train)=3.8962 | Train=47.10% | Test=43.18%|| Loss(test)=3.9544
# [Epoch 037] Loss(train)=3.8661 | Train=47.65% | Test=44.05%|| Loss(test)=3.9311
# [Epoch 038] Loss(train)=3.8361 | Train=48.40% | Test=43.55%|| Loss(test)=3.9207
# [Epoch 039] Loss(train)=3.8161 | Train=49.27% | Test=43.60%|| Loss(test)=3.8921
# [Epoch 040] Loss(train)=3.7889 | Train=49.65% | Test=43.25%|| Loss(test)=3.8804
# [Epoch 041] Loss(train)=3.7667 | Train=50.32% | Test=45.91%|| Loss(test)=3.8487
# [Epoch 042] Loss(train)=3.7402 | Train=49.93% | Test=45.94%|| Loss(test)=3.8346
# [Epoch 043] Loss(train)=3.7189 | Train=52.14% | Test=45.46%|| Loss(test)=3.8134
# [Epoch 044] Loss(train)=3.6951 | Train=52.95% | Test=44.67%|| Loss(test)=3.8049
# [Epoch 045] Loss(train)=3.6754 | Train=53.47% | Test=46.13%|| Loss(test)=3.7846
# [Epoch 046] Loss(train)=3.6572 | Train=53.67% | Test=46.25%|| Loss(test)=3.7746
# [Epoch 047] Loss(train)=3.6366 | Train=54.25% | Test=45.08%|| Loss(test)=3.7538
# [Epoch 048] Loss(train)=3.6179 | Train=54.62% | Test=45.13%|| Loss(test)=3.7435
# [Epoch 049] Loss(train)=3.5971 | Train=55.89% | Test=46.82%|| Loss(test)=3.7260
# [Epoch 050] Loss(train)=3.5781 | Train=56.76% | Test=47.55%|| Loss(test)=3.7063
# [Epoch 051] Loss(train)=3.5612 | Train=57.52% | Test=47.65%|| Loss(test)=3.7012
# [Epoch 052] Loss(train)=3.5456 | Train=57.69% | Test=48.38%|| Loss(test)=3.6851
# [Epoch 053] Loss(train)=3.5298 | Train=57.37% | Test=48.15%|| Loss(test)=3.6747
# [Epoch 054] Loss(train)=3.5127 | Train=58.39% | Test=48.91%|| Loss(test)=3.6654
# [Epoch 055] Loss(train)=3.4980 | Train=59.18% | Test=49.43%|| Loss(test)=3.6515
# [Epoch 056] Loss(train)=3.4839 | Train=59.34% | Test=49.90%|| Loss(test)=3.6429
# [Epoch 057] Loss(train)=3.4715 | Train=59.51% | Test=49.00%|| Loss(test)=3.6343
# [Epoch 058] Loss(train)=3.4568 | Train=60.66% | Test=49.17%|| Loss(test)=3.6275
# [Epoch 059] Loss(train)=3.4461 | Train=60.89% | Test=50.19%|| Loss(test)=3.6153
# [Epoch 060] Loss(train)=3.4345 | Train=61.06% | Test=49.97%|| Loss(test)=3.6092
# [Epoch 061] Loss(train)=3.4245 | Train=61.61% | Test=50.40%|| Loss(test)=3.5971
# [Epoch 062] Loss(train)=3.4076 | Train=62.26% | Test=50.19%|| Loss(test)=3.5872
# [Epoch 063] Loss(train)=3.4015 | Train=61.75% | Test=49.90%|| Loss(test)=3.5936
# [Epoch 064] Loss(train)=3.3932 | Train=63.26% | Test=50.78%|| Loss(test)=3.5777
# [Epoch 065] Loss(train)=3.3830 | Train=63.05% | Test=51.26%|| Loss(test)=3.5604
# [Epoch 066] Loss(train)=3.3726 | Train=63.18% | Test=51.19%|| Loss(test)=3.5595
# [Epoch 067] Loss(train)=3.3613 | Train=64.03% | Test=51.24%|| Loss(test)=3.5516
# [Epoch 068] Loss(train)=3.3531 | Train=64.85% | Test=51.47%|| Loss(test)=3.5462
# [Epoch 069] Loss(train)=3.3481 | Train=64.18% | Test=51.81%|| Loss(test)=3.5392
# [Epoch 070] Loss(train)=3.3450 | Train=65.78% | Test=51.40%|| Loss(test)=3.5349
# [Epoch 071] Loss(train)=3.3366 | Train=65.38% | Test=51.26%|| Loss(test)=3.5346
# [Epoch 072] Loss(train)=3.3278 | Train=65.23% | Test=51.98%|| Loss(test)=3.5282
# [Epoch 073] Loss(train)=3.3231 | Train=65.87% | Test=52.16%|| Loss(test)=3.5232
# [Epoch 074] Loss(train)=3.3159 | Train=65.88% | Test=51.95%|| Loss(test)=3.5183
# [Epoch 075] Loss(train)=3.3129 | Train=65.77% | Test=52.00%|| Loss(test)=3.5124
# [Epoch 076] Loss(train)=3.3056 | Train=66.20% | Test=51.93%|| Loss(test)=3.5103
# [Epoch 077] Loss(train)=3.2984 | Train=67.40% | Test=52.42%|| Loss(test)=3.5045
# [Epoch 078] Loss(train)=3.2981 | Train=66.68% | Test=52.23%|| Loss(test)=3.5078
# [Epoch 079] Loss(train)=3.2902 | Train=67.68% | Test=52.14%|| Loss(test)=3.5042
# [Epoch 080] Loss(train)=3.2884 | Train=67.75% | Test=51.86%|| Loss(test)=3.5020
# [Epoch 081] Loss(train)=3.2842 | Train=67.83% | Test=51.93%|| Loss(test)=3.5009
# [Epoch 082] Loss(train)=3.2811 | Train=67.75% | Test=52.12%|| Loss(test)=3.4967
# [Epoch 083] Loss(train)=3.2795 | Train=67.82% | Test=52.16%|| Loss(test)=3.4954
# [Epoch 084] Loss(train)=3.2794 | Train=67.53% | Test=52.36%|| Loss(test)=3.4920
# [Epoch 085] Loss(train)=3.2727 | Train=67.77% | Test=52.26%|| Loss(test)=3.4910
# [Epoch 086] Loss(train)=3.2719 | Train=67.68% | Test=52.71%|| Loss(test)=3.4898
# [Epoch 087] Loss(train)=3.2710 | Train=67.50% | Test=52.21%|| Loss(test)=3.4901
# [Epoch 088] Loss(train)=3.2701 | Train=68.79% | Test=52.33%|| Loss(test)=3.4888
# [Epoch 089] Loss(train)=3.2666 | Train=68.75% | Test=52.66%|| Loss(test)=3.4866
# [Epoch 090] Loss(train)=3.2673 | Train=68.23% | Test=52.71%|| Loss(test)=3.4845
# [Epoch 091] Loss(train)=3.2652 | Train=68.75% | Test=52.74%|| Loss(test)=3.4835
# [Epoch 092] Loss(train)=3.2663 | Train=68.79% | Test=52.88%|| Loss(test)=3.4822
# [Epoch 093] Loss(train)=3.2604 | Train=69.97% | Test=52.43%|| Loss(test)=3.4844
# [Epoch 094] Loss(train)=3.2620 | Train=68.60% | Test=52.78%|| Loss(test)=3.4837
# [Epoch 095] Loss(train)=3.2633 | Train=69.32% | Test=52.78%|| Loss(test)=3.4839
# [Epoch 096] Loss(train)=3.2627 | Train=68.85% | Test=52.68%|| Loss(test)=3.4828
# [Epoch 097] Loss(train)=3.2581 | Train=68.95% | Test=52.62%|| Loss(test)=3.4840
# [Epoch 098] Loss(train)=3.2631 | Train=68.62% | Test=52.68%|| Loss(test)=3.4836
# [Epoch 099] Loss(train)=3.2628 | Train=69.59% | Test=52.55%|| Loss(test)=3.4826
# [Epoch 100] Loss(train)=3.2600 | Train=68.54% | Test=52.93%|| Loss(test)=3.4820
#
# >>> 2nd Stage Start <<<
#
# [Epoch 101] Loss(train)=3.2654 | Train=68.20% | Test=52.66%|| Loss(test)=3.4845
# [Epoch 102] Loss(train)=3.2620 | Train=68.35% | Test=52.61%|| Loss(test)=3.4815
# [Epoch 103] Loss(train)=3.2599 | Train=68.67% | Test=52.55%|| Loss(test)=3.4828
# [Epoch 104] Loss(train)=3.2520 | Train=69.42% | Test=52.83%|| Loss(test)=3.4769
# [Epoch 105] Loss(train)=3.2522 | Train=69.07% | Test=52.61%|| Loss(test)=3.4765
# [Epoch 106] Loss(train)=3.2524 | Train=68.03% | Test=52.59%|| Loss(test)=3.4726
# [Epoch 107] Loss(train)=3.2483 | Train=68.57% | Test=52.95%|| Loss(test)=3.4686
# [Epoch 108] Loss(train)=3.2425 | Train=69.27% | Test=52.80%|| Loss(test)=3.4671
# [Epoch 109] Loss(train)=3.2417 | Train=69.29% | Test=52.71%|| Loss(test)=3.4716
# [Epoch 110] Loss(train)=3.2406 | Train=69.04% | Test=52.78%|| Loss(test)=3.4632
# [Epoch 111] Loss(train)=3.2350 | Train=69.35% | Test=53.04%|| Loss(test)=3.4637
# [Epoch 112] Loss(train)=3.2308 | Train=69.72% | Test=53.18%|| Loss(test)=3.4594
# [Epoch 113] Loss(train)=3.2333 | Train=69.92% | Test=53.31%|| Loss(test)=3.4585
# [Epoch 114] Loss(train)=3.2267 | Train=69.52% | Test=53.33%|| Loss(test)=3.4561
# [Epoch 115] Loss(train)=3.2299 | Train=69.14% | Test=52.97%|| Loss(test)=3.4572
# [Epoch 116] Loss(train)=3.2231 | Train=69.82% | Test=53.35%|| Loss(test)=3.4527
# [Epoch 117] Loss(train)=3.2202 | Train=70.10% | Test=53.62%|| Loss(test)=3.4511
# [Epoch 118] Loss(train)=3.2154 | Train=70.17% | Test=53.45%|| Loss(test)=3.4485
# [Epoch 119] Loss(train)=3.2151 | Train=70.09% | Test=53.38%|| Loss(test)=3.4482
# [Epoch 120] Loss(train)=3.2057 | Train=70.94% | Test=53.47%|| Loss(test)=3.4463
# [Epoch 121] Loss(train)=3.2116 | Train=70.47% | Test=53.40%|| Loss(test)=3.4447
# [Epoch 122] Loss(train)=3.2054 | Train=70.30% | Test=53.68%|| Loss(test)=3.4413
# [Epoch 123] Loss(train)=3.2078 | Train=70.50% | Test=53.50%|| Loss(test)=3.4369
# [Epoch 124] Loss(train)=3.2022 | Train=70.84% | Test=53.59%|| Loss(test)=3.4389
# [Epoch 125] Loss(train)=3.2011 | Train=70.45% | Test=53.73%|| Loss(test)=3.4348
# [Epoch 126] Loss(train)=3.1953 | Train=70.67% | Test=54.12%|| Loss(test)=3.4345
# [Epoch 127] Loss(train)=3.1947 | Train=70.20% | Test=53.57%|| Loss(test)=3.4362
# [Epoch 128] Loss(train)=3.1913 | Train=71.19% | Test=53.75%|| Loss(test)=3.4297
# [Epoch 129] Loss(train)=3.1916 | Train=71.42% | Test=54.00%|| Loss(test)=3.4305
# [Epoch 130] Loss(train)=3.1867 | Train=71.39% | Test=53.62%|| Loss(test)=3.4313
# [Epoch 131] Loss(train)=3.1840 | Train=71.00% | Test=53.80%|| Loss(test)=3.4255
# [Epoch 132] Loss(train)=3.1808 | Train=71.84% | Test=53.61%|| Loss(test)=3.4252
# [Epoch 133] Loss(train)=3.1798 | Train=71.47% | Test=53.83%|| Loss(test)=3.4236
# [Epoch 134] Loss(train)=3.1779 | Train=71.00% | Test=53.62%|| Loss(test)=3.4240
# [Epoch 135] Loss(train)=3.1747 | Train=71.86% | Test=53.97%|| Loss(test)=3.4188
# [Epoch 136] Loss(train)=3.1726 | Train=71.50% | Test=54.09%|| Loss(test)=3.4184
# [Epoch 137] Loss(train)=3.1673 | Train=72.37% | Test=53.88%|| Loss(test)=3.4152
# [Epoch 138] Loss(train)=3.1699 | Train=72.42% | Test=54.02%|| Loss(test)=3.4144
# [Epoch 139] Loss(train)=3.1669 | Train=72.04% | Test=54.31%|| Loss(test)=3.4103
# [Epoch 140] Loss(train)=3.1612 | Train=72.16% | Test=54.19%|| Loss(test)=3.4090
# [Epoch 141] Loss(train)=3.1612 | Train=71.45% | Test=54.09%|| Loss(test)=3.4090
# [Epoch 142] Loss(train)=3.1590 | Train=72.42% | Test=54.33%|| Loss(test)=3.4061
# [Epoch 143] Loss(train)=3.1554 | Train=72.52% | Test=53.90%|| Loss(test)=3.4075
# [Epoch 144] Loss(train)=3.1551 | Train=72.47% | Test=54.12%|| Loss(test)=3.4044
# [Epoch 145] Loss(train)=3.1521 | Train=72.79% | Test=53.95%|| Loss(test)=3.4054
# [Epoch 146] Loss(train)=3.1479 | Train=73.17% | Test=53.92%|| Loss(test)=3.4049
# [Epoch 147] Loss(train)=3.1491 | Train=72.16% | Test=54.50%|| Loss(test)=3.3987
# [Epoch 148] Loss(train)=3.1436 | Train=72.82% | Test=54.59%|| Loss(test)=3.3978
# [Epoch 149] Loss(train)=3.1415 | Train=72.46% | Test=54.37%|| Loss(test)=3.3982
# [Epoch 150] Loss(train)=3.1432 | Train=72.59% | Test=54.75%|| Loss(test)=3.3954
# [Epoch 151] Loss(train)=3.1408 | Train=72.89% | Test=54.40%|| Loss(test)=3.3972
# [Epoch 152] Loss(train)=3.1369 | Train=73.49% | Test=54.54%|| Loss(test)=3.3929
# [Epoch 153] Loss(train)=3.1373 | Train=73.11% | Test=54.44%|| Loss(test)=3.3945
# [Epoch 154] Loss(train)=3.1330 | Train=72.92% | Test=54.76%|| Loss(test)=3.3910
# [Epoch 155] Loss(train)=3.1319 | Train=73.61% | Test=54.80%|| Loss(test)=3.3873
# [Epoch 156] Loss(train)=3.1343 | Train=73.09% | Test=54.82%|| Loss(test)=3.3880
# [Epoch 157] Loss(train)=3.1285 | Train=73.02% | Test=55.02%|| Loss(test)=3.3864
# [Epoch 158] Loss(train)=3.1279 | Train=72.89% | Test=54.52%|| Loss(test)=3.3871
# [Epoch 159] Loss(train)=3.1270 | Train=73.47% | Test=54.64%|| Loss(test)=3.3847
# [Epoch 160] Loss(train)=3.1213 | Train=73.89% | Test=54.94%|| Loss(test)=3.3822
# [Epoch 161] Loss(train)=3.1201 | Train=74.44% | Test=54.68%|| Loss(test)=3.3818
# [Epoch 162] Loss(train)=3.1196 | Train=73.46% | Test=54.63%|| Loss(test)=3.3824
# [Epoch 163] Loss(train)=3.1184 | Train=73.04% | Test=54.40%|| Loss(test)=3.3773
# [Epoch 164] Loss(train)=3.1186 | Train=73.29% | Test=54.61%|| Loss(test)=3.3811
# [Epoch 165] Loss(train)=3.1144 | Train=74.09% | Test=54.45%|| Loss(test)=3.3829
# [Epoch 166] Loss(train)=3.1144 | Train=73.76% | Test=54.42%|| Loss(test)=3.3795
# [Epoch 167] Loss(train)=3.1138 | Train=74.26% | Test=54.56%|| Loss(test)=3.3751
# [Epoch 168] Loss(train)=3.1102 | Train=74.06% | Test=55.18%|| Loss(test)=3.3743
# [Epoch 169] Loss(train)=3.1065 | Train=74.47% | Test=54.69%|| Loss(test)=3.3743
# [Epoch 170] Loss(train)=3.1075 | Train=74.29% | Test=54.85%|| Loss(test)=3.3756
# [Epoch 171] Loss(train)=3.1061 | Train=74.57% | Test=54.87%|| Loss(test)=3.3731
# [Epoch 172] Loss(train)=3.1044 | Train=74.41% | Test=55.01%|| Loss(test)=3.3724
# [Epoch 173] Loss(train)=3.1019 | Train=74.84% | Test=54.52%|| Loss(test)=3.3716
# [Epoch 174] Loss(train)=3.1005 | Train=74.79% | Test=55.02%|| Loss(test)=3.3664
# [Epoch 175] Loss(train)=3.1020 | Train=74.42% | Test=54.66%|| Loss(test)=3.3683
# [Epoch 176] Loss(train)=3.0995 | Train=74.32% | Test=55.14%|| Loss(test)=3.3665
# [Epoch 177] Loss(train)=3.0970 | Train=74.69% | Test=55.16%|| Loss(test)=3.3654
# [Epoch 178] Loss(train)=3.0973 | Train=75.11% | Test=55.13%|| Loss(test)=3.3642
# [Epoch 179] Loss(train)=3.0938 | Train=74.72% | Test=55.35%|| Loss(test)=3.3640
# [Epoch 180] Loss(train)=3.0948 | Train=74.84% | Test=55.06%|| Loss(test)=3.3646
# [Epoch 181] Loss(train)=3.0932 | Train=74.87% | Test=55.11%|| Loss(test)=3.3628
# [Epoch 182] Loss(train)=3.0916 | Train=74.77% | Test=55.09%|| Loss(test)=3.3602
# [Epoch 183] Loss(train)=3.0915 | Train=75.09% | Test=55.23%|| Loss(test)=3.3587
# [Epoch 184] Loss(train)=3.0874 | Train=74.61% | Test=55.28%|| Loss(test)=3.3596
# [Epoch 185] Loss(train)=3.0872 | Train=74.84% | Test=55.42%|| Loss(test)=3.3566
# [Epoch 186] Loss(train)=3.0849 | Train=75.68% | Test=55.64%|| Loss(test)=3.3557
# [Epoch 187] Loss(train)=3.0838 | Train=75.46% | Test=54.99%|| Loss(test)=3.3593
# [Epoch 188] Loss(train)=3.0833 | Train=75.06% | Test=54.99%|| Loss(test)=3.3580
# [Epoch 189] Loss(train)=3.0835 | Train=75.56% | Test=55.45%|| Loss(test)=3.3567
# [Epoch 190] Loss(train)=3.0849 | Train=74.81% | Test=55.11%|| Loss(test)=3.3546
# [Epoch 191] Loss(train)=3.0810 | Train=75.53% | Test=55.23%|| Loss(test)=3.3536
# [Epoch 192] Loss(train)=3.0811 | Train=75.03% | Test=55.35%|| Loss(test)=3.3545
# [Epoch 193] Loss(train)=3.0836 | Train=75.34% | Test=55.59%|| Loss(test)=3.3518
# [Epoch 194] Loss(train)=3.0810 | Train=74.97% | Test=55.42%|| Loss(test)=3.3524
# [Epoch 195] Loss(train)=3.0796 | Train=74.92% | Test=55.21%|| Loss(test)=3.3501
# [Epoch 196] Loss(train)=3.0767 | Train=75.68% | Test=55.16%|| Loss(test)=3.3534
# [Epoch 197] Loss(train)=3.0740 | Train=75.84% | Test=54.95%|| Loss(test)=3.3525
# [Epoch 198] Loss(train)=3.0770 | Train=75.28% | Test=55.66%|| Loss(test)=3.3487
# [Epoch 199] Loss(train)=3.0740 | Train=75.76% | Test=55.33%|| Loss(test)=3.3484
# [Epoch 200] Loss(train)=3.0762 | Train=75.21% | Test=55.35%|| Loss(test)=3.3467
# [Epoch 201] Loss(train)=3.0753 | Train=75.48% | Test=55.40%|| Loss(test)=3.3485
# [Epoch 202] Loss(train)=3.0722 | Train=75.79% | Test=55.45%|| Loss(test)=3.3477
# [Epoch 203] Loss(train)=3.0727 | Train=75.91% | Test=55.44%|| Loss(test)=3.3459
# [Epoch 204] Loss(train)=3.0713 | Train=76.18% | Test=55.33%|| Loss(test)=3.3473
# [Epoch 205] Loss(train)=3.0741 | Train=75.74% | Test=55.64%|| Loss(test)=3.3481
# [Epoch 206] Loss(train)=3.0707 | Train=76.33% | Test=55.20%|| Loss(test)=3.3489
# [Epoch 207] Loss(train)=3.0705 | Train=75.86% | Test=55.30%|| Loss(test)=3.3474
# [Epoch 208] Loss(train)=3.0691 | Train=76.36% | Test=55.37%|| Loss(test)=3.3451
# [Epoch 209] Loss(train)=3.0669 | Train=76.39% | Test=55.59%|| Loss(test)=3.3448
# [Epoch 210] Loss(train)=3.0679 | Train=76.04% | Test=55.14%|| Loss(test)=3.3470
# [Epoch 211] Loss(train)=3.0677 | Train=76.36% | Test=55.87%|| Loss(test)=3.3446
# [Epoch 212] Loss(train)=3.0678 | Train=75.88% | Test=55.63%|| Loss(test)=3.3445
# [Epoch 213] Loss(train)=3.0698 | Train=76.09% | Test=55.64%|| Loss(test)=3.3442
# [Epoch 214] Loss(train)=3.0675 | Train=76.48% | Test=55.70%|| Loss(test)=3.3432
# [Epoch 215] Loss(train)=3.0673 | Train=75.73% | Test=55.44%|| Loss(test)=3.3431
# [Epoch 216] Loss(train)=3.0680 | Train=76.16% | Test=55.76%|| Loss(test)=3.3427
# [Epoch 217] Loss(train)=3.0676 | Train=75.79% | Test=55.56%|| Loss(test)=3.3439
# [Epoch 218] Loss(train)=3.0647 | Train=76.24% | Test=55.82%|| Loss(test)=3.3422
# [Epoch 219] Loss(train)=3.0641 | Train=75.64% | Test=55.76%|| Loss(test)=3.3420
# [Epoch 220] Loss(train)=3.0625 | Train=76.08% | Test=55.99%|| Loss(test)=3.3413
# [Epoch 221] Loss(train)=3.0637 | Train=76.38% | Test=55.57%|| Loss(test)=3.3442
# [Epoch 222] Loss(train)=3.0635 | Train=76.61% | Test=55.56%|| Loss(test)=3.3439
# [Epoch 223] Loss(train)=3.0644 | Train=75.96% | Test=55.76%|| Loss(test)=3.3447
# [Epoch 224] Loss(train)=3.0653 | Train=76.13% | Test=55.70%|| Loss(test)=3.3428
# [Epoch 225] Loss(train)=3.0648 | Train=76.28% | Test=55.45%|| Loss(test)=3.3436
# [Epoch 226] Loss(train)=3.0661 | Train=75.91% | Test=55.76%|| Loss(test)=3.3392
# [Epoch 227] Loss(train)=3.0622 | Train=76.64% | Test=55.61%|| Loss(test)=3.3399
# [Epoch 228] Loss(train)=3.0644 | Train=76.73% | Test=55.44%|| Loss(test)=3.3435
# [Epoch 229] Loss(train)=3.0630 | Train=76.31% | Test=55.61%|| Loss(test)=3.3431
# [Epoch 230] Loss(train)=3.0626 | Train=76.46% | Test=55.73%|| Loss(test)=3.3398
# [Epoch 231] Loss(train)=3.0618 | Train=76.23% | Test=55.47%|| Loss(test)=3.3430
# [Epoch 232] Loss(train)=3.0612 | Train=76.69% | Test=55.70%|| Loss(test)=3.3412
# [Epoch 233] Loss(train)=3.0622 | Train=76.33% | Test=55.70%|| Loss(test)=3.3403
# [Epoch 234] Loss(train)=3.0619 | Train=76.53% | Test=55.80%|| Loss(test)=3.3420
# [Epoch 235] Loss(train)=3.0608 | Train=75.96% | Test=55.63%|| Loss(test)=3.3390
# [Epoch 236] Loss(train)=3.0610 | Train=76.36% | Test=55.85%|| Loss(test)=3.3389
# [Epoch 237] Loss(train)=3.0598 | Train=76.84% | Test=55.57%|| Loss(test)=3.3396
# [Epoch 238] Loss(train)=3.0629 | Train=76.44% | Test=55.63%|| Loss(test)=3.3412
# [Epoch 239] Loss(train)=3.0616 | Train=76.21% | Test=55.66%|| Loss(test)=3.3407
# [Epoch 240] Loss(train)=3.0625 | Train=76.18% | Test=55.70%|| Loss(test)=3.3403
# [Epoch 241] Loss(train)=3.0609 | Train=76.09% | Test=55.61%|| Loss(test)=3.3425
# [Epoch 242] Loss(train)=3.0631 | Train=76.03% | Test=55.45%|| Loss(test)=3.3417
# [Epoch 243] Loss(train)=3.0612 | Train=76.29% | Test=55.51%|| Loss(test)=3.3412
# [Epoch 244] Loss(train)=3.0603 | Train=76.61% | Test=55.82%|| Loss(test)=3.3407
# [Epoch 245] Loss(train)=3.0619 | Train=76.06% | Test=55.40%|| Loss(test)=3.3421
# [Epoch 246] Loss(train)=3.0620 | Train=75.76% | Test=55.80%|| Loss(test)=3.3400
# [Epoch 247] Loss(train)=3.0622 | Train=76.38% | Test=55.47%|| Loss(test)=3.3429
# [Epoch 248] Loss(train)=3.0600 | Train=76.99% | Test=55.51%|| Loss(test)=3.3412
# [Epoch 249] Loss(train)=3.0641 | Train=76.69% | Test=55.63%|| Loss(test)=3.3399
# [Epoch 250] Loss(train)=3.0634 | Train=76.84% | Test=55.63%|| Loss(test)=3.3396

# %%
plt.figure(figsize=(6, 4))
plt.subplot(1,2,1)
plt.plot(tr_loss_hist, label="Train Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.subplot(1,2,2)
plt.plot(te_acc_hist, label="Test Acc")
plt.xlabel("Epoch")
plt.ylabel("Test Accuracy")
plt.title(f"Bilinear CNN Fine-Tuning (Two-Phase) | Best Test Acc = {best_acc*100:.2f}%")
plt.legend()
plt.tight_layout()
plt.show()
