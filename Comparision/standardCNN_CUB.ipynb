# %%
import os, time, random, gc
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from tqdm import tqdm
import pandas as pd

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATA_ROOT = "data/CUB_200_2011"
NUM_CLASSES = 200
INIT_LR = 1e-4
MID_LR = 1e-5
FINAL_LR = 1e-6
WEIGHT_DECAY = 1e-4
BATCH_SIZE = 32
STEP_SIZE = 7
EPOCHS_STAGE1 = 10
EPOCHS_STAGE2 = 100
EPOCHS_STAGE3 = 200
SEED = 87

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.5, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
    transforms.RandomRotation(degrees=15),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

class CUBDataset(Dataset):
    def __init__(self, root, train=True, transform=None):
        img_txt = os.path.join(root, "images.txt")
        label_txt = os.path.join(root, "image_class_labels.txt")
        split_txt = os.path.join(root, "train_test_split.txt")

        with open(img_txt) as f:
            imgs = [x.strip().split(" ") for x in f.readlines()]
        with open(label_txt) as f:
            labels = [int(x.strip().split(" ")[1]) - 1 for x in f.readlines()]
        with open(split_txt) as f:
            split = [int(x.strip().split(" ")[1]) for x in f.readlines()]

        self.samples = []
        for (img_id, img_path), label, is_train in zip(imgs, labels, split):
            if (train and is_train == 1) or (not train and is_train == 0):
                self.samples.append((os.path.join(root, "images", img_path), label))
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        img = Image.open(img_path).convert("RGB")
        if self.transform:
            img = self.transform(img)
        return img, label

train_loader = DataLoader(
    CUBDataset(DATA_ROOT, True, train_transforms),
    batch_size=BATCH_SIZE, shuffle=True, num_workers=10,
    pin_memory=True, persistent_workers=True, prefetch_factor=4
)
test_loader = DataLoader(
    CUBDataset(DATA_ROOT, False, test_transforms),
    batch_size=BATCH_SIZE, shuffle=False, num_workers=10,
    pin_memory=True, persistent_workers=True, prefetch_factor=4
)

def mixup_data(x, y, alpha=0.2, device='cuda'):
    lam = np.random.beta(alpha, alpha) if alpha > 0 else 1
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(device)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

@torch.no_grad()
def evaluate_model(model, loader, criterion, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    for images, labels in loader:
        images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)
        outputs = model(images)
        loss = criterion(outputs, labels)
        total_loss += loss.item() * labels.size(0)
        correct += (outputs.argmax(1) == labels).sum().item()
        total += labels.size(0)
    return 100 * correct / total, total_loss / total

def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    running_loss, total = 0.0, 0

    for images, labels in loader:
        images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)

        # MixUp
        mixed_imgs, y_a, y_b, lam = mixup_data(images, labels, device=device)

        optimizer.zero_grad()
        outputs = model(mixed_imgs)
        loss = mixup_criterion(criterion, outputs, y_a, y_b, lam)

        # correctly accumulate *sample-level* loss
        running_loss += loss.item() * labels.size(0)
        total += labels.size(0)

        loss.backward()
        optimizer.step()

    return running_loss / total

# %%
class VGG16CNN(nn.Module):
    def __init__(self, num_classes=NUM_CLASSES,pretrained=True):
        super().__init__()
        backbone = models.vgg16_bn(weights=models.VGG16_BN_Weights.IMAGENET1K_V1 if pretrained else None)
        # Extract features
        self.features = backbone.features # [B,512,7,7]
        
        # Extract classifier but replace last FC
        classifier=list(backbone.classifier.children())
        in_features=classifier[-1].in_features
        classifier[-1]=nn.Linear(in_features,num_classes)
        self.classifier=nn.Sequential(*classifier)

    def forward(self, x):
        x = self.features(x)
        x=torch.flatten(x,1)
        return self.classifier(x)

# %%
def run_training_3stage(model_name, model):
    print("=== Training ===")
    criterion = nn.CrossEntropyLoss()

    # ============================================================
    # Stage 1: Train classifier only (linear probing)
    # ============================================================
    for p in model.features.parameters(): 
        p.requires_grad = False
    for p in model.classifier.parameters(): 
        p.requires_grad = True

    print("--- Stage 1 ---")
    optimizer = optim.AdamW(model.classifier.parameters(), lr=INIT_LR, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=STEP_SIZE, gamma=0.1)

    stage1_hist = []
    for epoch in range(EPOCHS_STAGE1):
        tr_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
        te_acc, te_loss = evaluate_model(model, test_loader, criterion, DEVICE)
        scheduler.step()

        stage1_hist.append((epoch+1, tr_loss, te_loss, te_acc))

        print(f"[S1-Epoch {epoch+1:02d}] "
              f"Train Loss={tr_loss:.4f} | Test Loss={te_loss:.4f} | Test Acc={te_acc:.2f}%")


    # ============================================================
    # Stage 2: Fine-tune entire network (moderate LR)
    # ============================================================
    for p in model.parameters():
        p.requires_grad = True

    print("--- Stage 2---")
    optimizer = optim.AdamW(model.parameters(), lr=MID_LR, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=EPOCHS_STAGE2, gamma=0.1)

    stage2_hist = []
    best_acc = 0.0

    for epoch in range(EPOCHS_STAGE2):
        tr_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
        te_acc, te_loss = evaluate_model(model, test_loader, criterion, DEVICE)
        scheduler.step()

        stage2_hist.append((epoch+1, tr_loss, te_loss, te_acc))

        if te_acc > best_acc:
            best_acc = te_acc
            torch.save(model.state_dict(), f"best_{model_name}.pt")

        print(f"[S2-Epoch {epoch+1:03d}] "
              f"Train Loss={tr_loss:.4f} | Test Loss={te_loss:.4f} | Test Acc={te_acc:.2f}%")


    # ============================================================
    # Stage 3: Low-LR refinement (very small LR)
    # ============================================================
    print("--- Stage 3---")
    optimizer = optim.AdamW(model.parameters(), lr=FINAL_LR, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=EPOCHS_STAGE3, gamma=0.1)

    stage3_hist = []

    for epoch in range(EPOCHS_STAGE3):
        tr_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
        te_acc, te_loss = evaluate_model(model, test_loader, criterion, DEVICE)
        scheduler.step()

        stage3_hist.append((epoch+1, tr_loss, te_loss, te_acc))

        print(f"[S3-Epoch {epoch+1:03d}] "
              f"Train Loss={tr_loss:.4f} | Test Loss={te_loss:.4f} | Test Acc={te_acc:.2f}%")


    return stage1_hist, stage2_hist, stage3_hist

# %%
gc.collect()
torch.cuda.empty_cache()

results = {}
model=VGG16CNN(num_classes=NUM_CLASSES,pretrained=True).to(DEVICE)
for name, model_fn in [("StandardCNN", VGG16CNN)]:
    model = model_fn().to(DEVICE)
    s1, s2, s3 = run_training_3stage(name, model)
    df1 = pd.DataFrame(s1, columns=["epoch", "train_loss", "test_loss", "test_acc"])
    df1["stage"] = "Stage 1"
    df1["model"] = name
    
    df2 = pd.DataFrame(s2, columns=["epoch", "train_loss", "test_loss", "test_acc"])
    df2["stage"] = "Stage 2"
    df2["model"] = name
    
    df3 = pd.DataFrame(s3, columns=["epoch", "train_loss", "test_loss", "test_acc"])
    df3["stage"] = "Stage 3"
    df3["model"] = name
    hist = pd.concat([df1, df2, df3], ignore_index=True)
# Out:
# === Training ===
# --- Stage 1 ---
# [S1-Epoch 01] Train Loss=4.7204 | Test Loss=3.0511 | Test Acc=28.89%
# [S1-Epoch 02] Train Loss=3.5819 | Test Loss=2.3102 | Test Acc=42.08%
# [S1-Epoch 03] Train Loss=3.0392 | Test Loss=1.9988 | Test Acc=46.84%
# [S1-Epoch 04] Train Loss=2.8223 | Test Loss=1.7977 | Test Acc=50.66%
# [S1-Epoch 05] Train Loss=2.7640 | Test Loss=1.7847 | Test Acc=53.00%
# [S1-Epoch 06] Train Loss=2.5530 | Test Loss=1.5985 | Test Acc=56.35%
# [S1-Epoch 07] Train Loss=2.6040 | Test Loss=1.6375 | Test Acc=55.32%
# [S1-Epoch 08] Train Loss=2.2648 | Test Loss=1.4827 | Test Acc=59.25%
# [S1-Epoch 09] Train Loss=2.1610 | Test Loss=1.4325 | Test Acc=60.08%
# [S1-Epoch 10] Train Loss=2.1137 | Test Loss=1.4216 | Test Acc=60.60%
# --- Stage 2---
# [S2-Epoch 001] Train Loss=2.0755 | Test Loss=1.3562 | Test Acc=62.56%
# [S2-Epoch 002] Train Loss=1.9295 | Test Loss=1.2688 | Test Acc=65.41%
# [S2-Epoch 003] Train Loss=1.8446 | Test Loss=1.2146 | Test Acc=66.07%
# [S2-Epoch 004] Train Loss=1.6840 | Test Loss=1.1996 | Test Acc=67.05%
# [S2-Epoch 005] Train Loss=1.6326 | Test Loss=1.1808 | Test Acc=67.24%
# [S2-Epoch 006] Train Loss=1.8794 | Test Loss=1.1698 | Test Acc=68.12%
# [S2-Epoch 007] Train Loss=1.7496 | Test Loss=1.1253 | Test Acc=69.28%
# [S2-Epoch 008] Train Loss=1.7147 | Test Loss=1.0935 | Test Acc=69.73%
# [S2-Epoch 009] Train Loss=1.6480 | Test Loss=1.0877 | Test Acc=70.04%
# [S2-Epoch 010] Train Loss=1.6166 | Test Loss=1.0742 | Test Acc=70.04%
# [S2-Epoch 011] Train Loss=1.5720 | Test Loss=1.0734 | Test Acc=70.33%
# [S2-Epoch 012] Train Loss=1.5540 | Test Loss=1.0609 | Test Acc=71.11%
# [S2-Epoch 013] Train Loss=1.4686 | Test Loss=1.0325 | Test Acc=71.44%
# [S2-Epoch 014] Train Loss=1.4473 | Test Loss=1.0026 | Test Acc=72.02%
# [S2-Epoch 015] Train Loss=1.4734 | Test Loss=1.0339 | Test Acc=71.78%
# [S2-Epoch 016] Train Loss=1.4346 | Test Loss=0.9922 | Test Acc=72.11%
# [S2-Epoch 017] Train Loss=1.4659 | Test Loss=1.0148 | Test Acc=71.80%
# [S2-Epoch 018] Train Loss=1.3531 | Test Loss=0.9794 | Test Acc=71.95%
# [S2-Epoch 019] Train Loss=1.4751 | Test Loss=1.0279 | Test Acc=72.42%
# [S2-Epoch 020] Train Loss=1.2622 | Test Loss=0.9757 | Test Acc=72.70%
# [S2-Epoch 021] Train Loss=1.3066 | Test Loss=0.9943 | Test Acc=72.42%
# [S2-Epoch 022] Train Loss=1.2901 | Test Loss=0.9800 | Test Acc=72.80%
# [S2-Epoch 023] Train Loss=1.3467 | Test Loss=0.9521 | Test Acc=73.21%
# [S2-Epoch 024] Train Loss=1.4317 | Test Loss=0.9833 | Test Acc=73.25%
# [S2-Epoch 025] Train Loss=1.4997 | Test Loss=0.9855 | Test Acc=73.14%
# [S2-Epoch 026] Train Loss=1.1387 | Test Loss=0.9790 | Test Acc=73.80%
# [S2-Epoch 027] Train Loss=1.2850 | Test Loss=0.9384 | Test Acc=73.77%
# [S2-Epoch 028] Train Loss=1.2634 | Test Loss=0.9664 | Test Acc=74.25%
# [S2-Epoch 029] Train Loss=1.2192 | Test Loss=0.9663 | Test Acc=74.08%
# [S2-Epoch 030] Train Loss=1.1893 | Test Loss=0.9731 | Test Acc=74.09%
# [S2-Epoch 031] Train Loss=1.1769 | Test Loss=0.9616 | Test Acc=74.13%
# [S2-Epoch 032] Train Loss=1.1582 | Test Loss=0.9585 | Test Acc=74.02%
# [S2-Epoch 033] Train Loss=1.2229 | Test Loss=0.9415 | Test Acc=74.28%
# [S2-Epoch 034] Train Loss=1.1938 | Test Loss=0.9256 | Test Acc=74.42%
# [S2-Epoch 035] Train Loss=1.0682 | Test Loss=0.9439 | Test Acc=74.56%
# [S2-Epoch 036] Train Loss=1.1052 | Test Loss=0.9494 | Test Acc=74.51%
# [S2-Epoch 037] Train Loss=1.1223 | Test Loss=0.9455 | Test Acc=74.70%
# [S2-Epoch 038] Train Loss=1.0766 | Test Loss=0.9386 | Test Acc=74.16%
# [S2-Epoch 039] Train Loss=1.1372 | Test Loss=0.9380 | Test Acc=74.73%
# [S2-Epoch 040] Train Loss=1.1359 | Test Loss=0.9449 | Test Acc=75.20%
# [S2-Epoch 041] Train Loss=1.2579 | Test Loss=0.9342 | Test Acc=74.89%
# [S2-Epoch 042] Train Loss=1.2267 | Test Loss=0.9388 | Test Acc=74.78%
# [S2-Epoch 043] Train Loss=1.1309 | Test Loss=0.9091 | Test Acc=75.53%
# [S2-Epoch 044] Train Loss=1.1713 | Test Loss=0.9274 | Test Acc=74.75%
# [S2-Epoch 045] Train Loss=1.1210 | Test Loss=0.9220 | Test Acc=75.15%
# [S2-Epoch 046] Train Loss=1.1832 | Test Loss=0.9452 | Test Acc=74.73%
# [S2-Epoch 047] Train Loss=1.0823 | Test Loss=0.9310 | Test Acc=75.09%
# [S2-Epoch 048] Train Loss=0.9344 | Test Loss=0.9156 | Test Acc=74.99%
# [S2-Epoch 049] Train Loss=0.9758 | Test Loss=0.9244 | Test Acc=75.54%
# [S2-Epoch 050] Train Loss=1.1542 | Test Loss=0.9807 | Test Acc=74.75%
# [S2-Epoch 051] Train Loss=1.0808 | Test Loss=0.9423 | Test Acc=75.25%
# [S2-Epoch 052] Train Loss=1.1645 | Test Loss=0.9403 | Test Acc=75.41%
# [S2-Epoch 053] Train Loss=1.0601 | Test Loss=0.9135 | Test Acc=75.68%
# [S2-Epoch 054] Train Loss=1.1484 | Test Loss=0.9574 | Test Acc=75.32%
# [S2-Epoch 055] Train Loss=1.2203 | Test Loss=0.9559 | Test Acc=75.25%
# [S2-Epoch 056] Train Loss=1.1826 | Test Loss=0.9457 | Test Acc=75.79%
# [S2-Epoch 057] Train Loss=1.0273 | Test Loss=0.9332 | Test Acc=75.75%
# [S2-Epoch 058] Train Loss=0.9702 | Test Loss=0.9086 | Test Acc=75.75%
# [S2-Epoch 059] Train Loss=0.8582 | Test Loss=0.9350 | Test Acc=75.68%
# [S2-Epoch 060] Train Loss=0.8133 | Test Loss=0.9305 | Test Acc=75.49%
# [S2-Epoch 061] Train Loss=1.0201 | Test Loss=0.9722 | Test Acc=75.34%
# [S2-Epoch 062] Train Loss=1.0823 | Test Loss=0.9571 | Test Acc=75.44%
# [S2-Epoch 063] Train Loss=0.9855 | Test Loss=0.9401 | Test Acc=75.63%
# [S2-Epoch 064] Train Loss=0.8748 | Test Loss=0.9353 | Test Acc=75.75%
# [S2-Epoch 065] Train Loss=0.8356 | Test Loss=0.9144 | Test Acc=75.70%
# [S2-Epoch 066] Train Loss=1.0734 | Test Loss=0.9258 | Test Acc=75.82%
# [S2-Epoch 067] Train Loss=0.8208 | Test Loss=0.8962 | Test Acc=76.06%
# [S2-Epoch 068] Train Loss=0.9385 | Test Loss=0.9491 | Test Acc=75.34%
# [S2-Epoch 069] Train Loss=0.8603 | Test Loss=0.9123 | Test Acc=75.42%
# [S2-Epoch 070] Train Loss=1.0225 | Test Loss=0.9120 | Test Acc=75.63%
# [S2-Epoch 071] Train Loss=0.9106 | Test Loss=0.9244 | Test Acc=75.98%
# [S2-Epoch 072] Train Loss=1.0399 | Test Loss=0.9247 | Test Acc=76.13%
# [S2-Epoch 073] Train Loss=0.8778 | Test Loss=0.9273 | Test Acc=76.25%
# [S2-Epoch 074] Train Loss=1.0075 | Test Loss=0.9485 | Test Acc=75.96%
# [S2-Epoch 075] Train Loss=0.9508 | Test Loss=0.9928 | Test Acc=75.27%
# [S2-Epoch 076] Train Loss=0.9025 | Test Loss=0.9029 | Test Acc=76.53%
# [S2-Epoch 077] Train Loss=0.9617 | Test Loss=0.9499 | Test Acc=75.98%
# [S2-Epoch 078] Train Loss=1.1118 | Test Loss=0.9106 | Test Acc=76.77%
# [S2-Epoch 079] Train Loss=0.9496 | Test Loss=1.0072 | Test Acc=75.75%
# [S2-Epoch 080] Train Loss=1.0203 | Test Loss=0.9359 | Test Acc=75.94%
# [S2-Epoch 081] Train Loss=0.9438 | Test Loss=0.9635 | Test Acc=75.73%
# [S2-Epoch 082] Train Loss=1.0130 | Test Loss=0.9311 | Test Acc=75.91%
# [S2-Epoch 083] Train Loss=0.8742 | Test Loss=0.9073 | Test Acc=76.04%
# [S2-Epoch 084] Train Loss=1.0356 | Test Loss=1.0032 | Test Acc=75.73%
# [S2-Epoch 085] Train Loss=0.9160 | Test Loss=0.9594 | Test Acc=76.18%
# [S2-Epoch 086] Train Loss=1.0108 | Test Loss=0.9415 | Test Acc=76.13%
# [S2-Epoch 087] Train Loss=0.8670 | Test Loss=0.9067 | Test Acc=76.42%
# [S2-Epoch 088] Train Loss=0.9077 | Test Loss=0.9555 | Test Acc=76.10%
# [S2-Epoch 089] Train Loss=0.9499 | Test Loss=0.9463 | Test Acc=76.58%
# [S2-Epoch 090] Train Loss=0.9282 | Test Loss=0.9083 | Test Acc=76.68%
# [S2-Epoch 091] Train Loss=0.9388 | Test Loss=0.9051 | Test Acc=77.10%
# [S2-Epoch 092] Train Loss=0.9218 | Test Loss=0.9105 | Test Acc=76.72%
# [S2-Epoch 093] Train Loss=0.8947 | Test Loss=0.9145 | Test Acc=76.82%
# [S2-Epoch 094] Train Loss=0.8796 | Test Loss=0.9500 | Test Acc=76.53%
# [S2-Epoch 095] Train Loss=0.8598 | Test Loss=0.9231 | Test Acc=76.44%
# [S2-Epoch 096] Train Loss=0.8932 | Test Loss=0.9437 | Test Acc=76.72%
# [S2-Epoch 097] Train Loss=0.8784 | Test Loss=0.9033 | Test Acc=76.99%
# [S2-Epoch 098] Train Loss=0.9017 | Test Loss=0.9502 | Test Acc=76.08%
# [S2-Epoch 099] Train Loss=0.9588 | Test Loss=0.9107 | Test Acc=76.39%
# [S2-Epoch 100] Train Loss=0.9234 | Test Loss=0.9228 | Test Acc=76.80%
# --- Stage 3---
# [S3-Epoch 001] Train Loss=1.0744 | Test Loss=0.9722 | Test Acc=76.32%
# [S3-Epoch 002] Train Loss=0.9344 | Test Loss=0.9114 | Test Acc=76.65%
# [S3-Epoch 003] Train Loss=0.8102 | Test Loss=0.9640 | Test Acc=76.11%
# [S3-Epoch 004] Train Loss=0.8358 | Test Loss=0.9276 | Test Acc=77.01%
# [S3-Epoch 005] Train Loss=0.8547 | Test Loss=0.9656 | Test Acc=76.53%
# [S3-Epoch 006] Train Loss=0.8086 | Test Loss=0.9087 | Test Acc=77.11%
# [S3-Epoch 007] Train Loss=0.9614 | Test Loss=0.9366 | Test Acc=76.84%
# [S3-Epoch 008] Train Loss=0.9945 | Test Loss=0.9477 | Test Acc=76.68%
# [S3-Epoch 009] Train Loss=0.8563 | Test Loss=0.9262 | Test Acc=76.94%
# [S3-Epoch 010] Train Loss=0.8420 | Test Loss=0.9194 | Test Acc=76.84%
# [S3-Epoch 011] Train Loss=0.7947 | Test Loss=0.9102 | Test Acc=76.91%
# [S3-Epoch 012] Train Loss=0.8508 | Test Loss=0.8799 | Test Acc=77.56%
# [S3-Epoch 013] Train Loss=0.8158 | Test Loss=0.8919 | Test Acc=77.32%
# [S3-Epoch 014] Train Loss=0.9189 | Test Loss=0.9202 | Test Acc=76.96%
# [S3-Epoch 015] Train Loss=0.8775 | Test Loss=0.9589 | Test Acc=76.54%
# [S3-Epoch 016] Train Loss=0.9561 | Test Loss=0.9137 | Test Acc=76.58%
# [S3-Epoch 017] Train Loss=0.7121 | Test Loss=0.9445 | Test Acc=76.82%
# [S3-Epoch 018] Train Loss=0.9298 | Test Loss=0.9127 | Test Acc=77.20%
# [S3-Epoch 019] Train Loss=0.8822 | Test Loss=0.9205 | Test Acc=76.96%
# [S3-Epoch 020] Train Loss=0.8552 | Test Loss=0.9068 | Test Acc=76.98%
# [S3-Epoch 021] Train Loss=0.8769 | Test Loss=0.9478 | Test Acc=76.91%
# [S3-Epoch 022] Train Loss=0.9525 | Test Loss=0.8972 | Test Acc=77.01%
# [S3-Epoch 023] Train Loss=0.9467 | Test Loss=0.9206 | Test Acc=76.80%
# [S3-Epoch 024] Train Loss=0.9377 | Test Loss=0.9306 | Test Acc=76.89%
# [S3-Epoch 025] Train Loss=0.9844 | Test Loss=0.9729 | Test Acc=76.61%
# [S3-Epoch 026] Train Loss=0.8856 | Test Loss=0.9179 | Test Acc=76.73%
# [S3-Epoch 027] Train Loss=0.8549 | Test Loss=0.9167 | Test Acc=76.91%
# [S3-Epoch 028] Train Loss=0.8439 | Test Loss=0.9025 | Test Acc=77.05%
# [S3-Epoch 029] Train Loss=0.7103 | Test Loss=0.9102 | Test Acc=76.86%
# [S3-Epoch 030] Train Loss=0.8482 | Test Loss=0.9292 | Test Acc=76.92%
# [S3-Epoch 031] Train Loss=0.8688 | Test Loss=0.9920 | Test Acc=76.42%
# [S3-Epoch 032] Train Loss=0.9134 | Test Loss=0.9360 | Test Acc=76.39%
# [S3-Epoch 033] Train Loss=0.9084 | Test Loss=0.9219 | Test Acc=76.92%
# [S3-Epoch 034] Train Loss=0.8902 | Test Loss=0.9734 | Test Acc=76.44%
# [S3-Epoch 035] Train Loss=0.8889 | Test Loss=1.0001 | Test Acc=76.67%
# [S3-Epoch 036] Train Loss=0.7914 | Test Loss=0.8936 | Test Acc=77.25%
# [S3-Epoch 037] Train Loss=0.9493 | Test Loss=0.9202 | Test Acc=77.10%
# [S3-Epoch 038] Train Loss=0.8732 | Test Loss=0.9751 | Test Acc=76.56%
# [S3-Epoch 039] Train Loss=0.6767 | Test Loss=0.8880 | Test Acc=77.20%
# [S3-Epoch 040] Train Loss=0.8016 | Test Loss=0.9152 | Test Acc=77.05%
# [S3-Epoch 041] Train Loss=0.8925 | Test Loss=0.9208 | Test Acc=77.05%
# [S3-Epoch 042] Train Loss=0.8545 | Test Loss=0.9255 | Test Acc=76.91%
# [S3-Epoch 043] Train Loss=0.8173 | Test Loss=0.9200 | Test Acc=76.99%
# [S3-Epoch 044] Train Loss=0.9966 | Test Loss=0.9711 | Test Acc=76.73%
# [S3-Epoch 045] Train Loss=0.8022 | Test Loss=0.9428 | Test Acc=76.94%
# [S3-Epoch 046] Train Loss=0.8560 | Test Loss=0.9286 | Test Acc=76.87%
# [S3-Epoch 047] Train Loss=0.8501 | Test Loss=0.9247 | Test Acc=77.05%
# [S3-Epoch 048] Train Loss=0.8801 | Test Loss=0.8841 | Test Acc=77.39%
# [S3-Epoch 049] Train Loss=0.9689 | Test Loss=0.9034 | Test Acc=77.30%
# [S3-Epoch 050] Train Loss=0.9922 | Test Loss=0.9041 | Test Acc=77.24%
# [S3-Epoch 051] Train Loss=0.7254 | Test Loss=0.9164 | Test Acc=77.32%
# [S3-Epoch 052] Train Loss=0.8146 | Test Loss=0.9063 | Test Acc=77.49%
# [S3-Epoch 053] Train Loss=0.8711 | Test Loss=0.9251 | Test Acc=77.27%
# [S3-Epoch 054] Train Loss=0.9068 | Test Loss=0.9057 | Test Acc=77.05%
# [S3-Epoch 055] Train Loss=0.9413 | Test Loss=0.9428 | Test Acc=77.22%
# [S3-Epoch 056] Train Loss=0.7933 | Test Loss=0.9027 | Test Acc=77.44%
# [S3-Epoch 057] Train Loss=0.7978 | Test Loss=0.8882 | Test Acc=77.49%
# [S3-Epoch 058] Train Loss=0.8848 | Test Loss=0.9734 | Test Acc=77.20%
# [S3-Epoch 059] Train Loss=0.8922 | Test Loss=0.9345 | Test Acc=76.99%
# [S3-Epoch 060] Train Loss=0.7575 | Test Loss=0.9064 | Test Acc=77.30%
# [S3-Epoch 061] Train Loss=0.7807 | Test Loss=0.9098 | Test Acc=77.44%
# [S3-Epoch 062] Train Loss=0.8709 | Test Loss=0.9189 | Test Acc=77.29%
# [S3-Epoch 063] Train Loss=0.7993 | Test Loss=0.8907 | Test Acc=77.44%
# [S3-Epoch 064] Train Loss=0.9252 | Test Loss=0.9199 | Test Acc=77.11%
# [S3-Epoch 065] Train Loss=0.8316 | Test Loss=0.8862 | Test Acc=77.46%
# [S3-Epoch 066] Train Loss=0.8979 | Test Loss=0.9795 | Test Acc=76.96%
# [S3-Epoch 067] Train Loss=0.8498 | Test Loss=0.9336 | Test Acc=76.91%
# [S3-Epoch 068] Train Loss=0.8292 | Test Loss=0.9362 | Test Acc=76.92%
# [S3-Epoch 069] Train Loss=0.8680 | Test Loss=0.9288 | Test Acc=77.37%
# [S3-Epoch 070] Train Loss=0.8354 | Test Loss=0.8956 | Test Acc=77.25%
# [S3-Epoch 071] Train Loss=0.7449 | Test Loss=0.9033 | Test Acc=77.65%
# [S3-Epoch 072] Train Loss=0.9895 | Test Loss=0.9203 | Test Acc=77.34%
# [S3-Epoch 073] Train Loss=1.0328 | Test Loss=0.9341 | Test Acc=77.05%
# [S3-Epoch 074] Train Loss=0.7757 | Test Loss=0.9508 | Test Acc=77.13%
# [S3-Epoch 075] Train Loss=1.0165 | Test Loss=0.9454 | Test Acc=77.06%
# [S3-Epoch 076] Train Loss=0.8642 | Test Loss=0.9469 | Test Acc=77.01%
# [S3-Epoch 077] Train Loss=0.9057 | Test Loss=0.9227 | Test Acc=77.18%
# [S3-Epoch 078] Train Loss=0.9010 | Test Loss=0.9406 | Test Acc=77.15%
# [S3-Epoch 079] Train Loss=0.9660 | Test Loss=0.9427 | Test Acc=76.89%
# [S3-Epoch 080] Train Loss=0.9865 | Test Loss=0.9057 | Test Acc=77.39%
# [S3-Epoch 081] Train Loss=0.8818 | Test Loss=0.9091 | Test Acc=77.44%
# [S3-Epoch 082] Train Loss=0.8766 | Test Loss=0.9140 | Test Acc=77.34%
# [S3-Epoch 083] Train Loss=0.9054 | Test Loss=0.9152 | Test Acc=77.08%
# [S3-Epoch 084] Train Loss=0.8477 | Test Loss=0.9043 | Test Acc=77.29%
# [S3-Epoch 085] Train Loss=0.8664 | Test Loss=0.9147 | Test Acc=77.36%
# [S3-Epoch 086] Train Loss=0.8799 | Test Loss=0.9231 | Test Acc=77.13%
# [S3-Epoch 087] Train Loss=0.9183 | Test Loss=0.9610 | Test Acc=77.18%
# [S3-Epoch 088] Train Loss=0.9436 | Test Loss=0.9217 | Test Acc=77.39%
# [S3-Epoch 089] Train Loss=0.8894 | Test Loss=0.9048 | Test Acc=77.67%
# [S3-Epoch 090] Train Loss=0.7350 | Test Loss=0.9141 | Test Acc=77.34%
# [S3-Epoch 091] Train Loss=0.9618 | Test Loss=0.9028 | Test Acc=77.44%
# [S3-Epoch 092] Train Loss=0.8485 | Test Loss=0.9335 | Test Acc=77.01%
# [S3-Epoch 093] Train Loss=0.6985 | Test Loss=0.9189 | Test Acc=77.34%
# [S3-Epoch 094] Train Loss=0.8659 | Test Loss=0.9390 | Test Acc=77.24%
# [S3-Epoch 095] Train Loss=0.8726 | Test Loss=0.8847 | Test Acc=77.58%
# [S3-Epoch 096] Train Loss=0.8619 | Test Loss=0.9159 | Test Acc=77.10%
# [S3-Epoch 097] Train Loss=0.8428 | Test Loss=1.0062 | Test Acc=76.60%
# [S3-Epoch 098] Train Loss=0.8671 | Test Loss=0.9349 | Test Acc=77.30%
# [S3-Epoch 099] Train Loss=0.8961 | Test Loss=0.9144 | Test Acc=77.29%
# [S3-Epoch 100] Train Loss=0.8456 | Test Loss=0.8830 | Test Acc=77.42%
# [S3-Epoch 101] Train Loss=0.9046 | Test Loss=0.9470 | Test Acc=76.94%
# [S3-Epoch 102] Train Loss=0.8840 | Test Loss=0.9450 | Test Acc=76.96%
# [S3-Epoch 103] Train Loss=0.9112 | Test Loss=0.9540 | Test Acc=76.77%
# [S3-Epoch 104] Train Loss=0.8167 | Test Loss=0.8771 | Test Acc=77.68%
# [S3-Epoch 105] Train Loss=0.8385 | Test Loss=0.9067 | Test Acc=77.46%
# [S3-Epoch 106] Train Loss=0.8988 | Test Loss=0.9176 | Test Acc=77.39%
# [S3-Epoch 107] Train Loss=0.9284 | Test Loss=0.9184 | Test Acc=77.32%
# [S3-Epoch 108] Train Loss=0.9265 | Test Loss=0.9390 | Test Acc=77.44%
# [S3-Epoch 109] Train Loss=0.8908 | Test Loss=0.9455 | Test Acc=77.13%
# [S3-Epoch 110] Train Loss=0.7068 | Test Loss=0.9262 | Test Acc=77.39%
# [S3-Epoch 111] Train Loss=0.9654 | Test Loss=0.9359 | Test Acc=77.36%
# [S3-Epoch 112] Train Loss=0.9894 | Test Loss=0.9276 | Test Acc=77.53%
# [S3-Epoch 113] Train Loss=0.8365 | Test Loss=0.9149 | Test Acc=77.10%
# [S3-Epoch 114] Train Loss=0.8624 | Test Loss=0.9391 | Test Acc=77.32%
# [S3-Epoch 115] Train Loss=0.9028 | Test Loss=0.9388 | Test Acc=77.30%
# [S3-Epoch 116] Train Loss=0.9641 | Test Loss=0.9550 | Test Acc=77.01%
# [S3-Epoch 117] Train Loss=0.8816 | Test Loss=0.9165 | Test Acc=77.36%
# [S3-Epoch 118] Train Loss=0.9065 | Test Loss=0.9554 | Test Acc=77.44%
# [S3-Epoch 119] Train Loss=0.9455 | Test Loss=0.9479 | Test Acc=77.39%
# [S3-Epoch 120] Train Loss=0.9455 | Test Loss=0.8989 | Test Acc=77.58%
# [S3-Epoch 121] Train Loss=0.8789 | Test Loss=0.9200 | Test Acc=77.34%
# [S3-Epoch 122] Train Loss=0.8978 | Test Loss=0.9812 | Test Acc=77.03%
# [S3-Epoch 123] Train Loss=0.8511 | Test Loss=0.9608 | Test Acc=77.17%
# [S3-Epoch 124] Train Loss=0.9627 | Test Loss=0.9102 | Test Acc=77.46%
# [S3-Epoch 125] Train Loss=0.7717 | Test Loss=0.9030 | Test Acc=77.18%
# [S3-Epoch 126] Train Loss=0.7449 | Test Loss=0.8950 | Test Acc=77.49%
# [S3-Epoch 127] Train Loss=0.8861 | Test Loss=0.8847 | Test Acc=77.58%
# [S3-Epoch 128] Train Loss=0.7845 | Test Loss=0.9137 | Test Acc=77.27%
# [S3-Epoch 129] Train Loss=0.8483 | Test Loss=0.9124 | Test Acc=77.37%
# [S3-Epoch 130] Train Loss=0.8784 | Test Loss=0.9495 | Test Acc=77.01%
# [S3-Epoch 131] Train Loss=0.7477 | Test Loss=0.9079 | Test Acc=77.41%
# [S3-Epoch 132] Train Loss=0.8297 | Test Loss=0.9175 | Test Acc=77.51%
# [S3-Epoch 133] Train Loss=0.9451 | Test Loss=0.8888 | Test Acc=77.53%
# [S3-Epoch 134] Train Loss=0.9813 | Test Loss=0.9083 | Test Acc=77.42%
# [S3-Epoch 135] Train Loss=0.8446 | Test Loss=0.8963 | Test Acc=77.79%
# [S3-Epoch 136] Train Loss=0.8605 | Test Loss=0.9665 | Test Acc=77.17%
# [S3-Epoch 137] Train Loss=0.7880 | Test Loss=0.9247 | Test Acc=77.65%
# [S3-Epoch 138] Train Loss=0.8522 | Test Loss=0.9364 | Test Acc=77.55%
# [S3-Epoch 139] Train Loss=0.9149 | Test Loss=0.9295 | Test Acc=77.37%
# [S3-Epoch 140] Train Loss=0.8451 | Test Loss=0.8884 | Test Acc=77.65%
# [S3-Epoch 141] Train Loss=0.8512 | Test Loss=0.9383 | Test Acc=77.41%
# [S3-Epoch 142] Train Loss=0.8702 | Test Loss=0.9132 | Test Acc=77.51%
# [S3-Epoch 143] Train Loss=0.8971 | Test Loss=0.9309 | Test Acc=77.60%
# [S3-Epoch 144] Train Loss=0.9093 | Test Loss=0.9166 | Test Acc=77.41%
# [S3-Epoch 145] Train Loss=0.9145 | Test Loss=0.8853 | Test Acc=77.82%
# [S3-Epoch 146] Train Loss=0.8531 | Test Loss=0.9288 | Test Acc=77.55%
# [S3-Epoch 147] Train Loss=0.9708 | Test Loss=0.9316 | Test Acc=77.44%
# [S3-Epoch 148] Train Loss=0.9680 | Test Loss=0.9449 | Test Acc=77.39%
# [S3-Epoch 149] Train Loss=0.8262 | Test Loss=0.9193 | Test Acc=77.58%
# [S3-Epoch 150] Train Loss=0.9447 | Test Loss=0.9328 | Test Acc=77.22%
# [S3-Epoch 151] Train Loss=0.9233 | Test Loss=0.9328 | Test Acc=77.30%
# [S3-Epoch 152] Train Loss=0.9313 | Test Loss=0.9086 | Test Acc=77.48%
# [S3-Epoch 153] Train Loss=0.9267 | Test Loss=0.8974 | Test Acc=77.36%
# [S3-Epoch 154] Train Loss=0.8742 | Test Loss=0.8936 | Test Acc=77.58%
# [S3-Epoch 155] Train Loss=0.9296 | Test Loss=0.9078 | Test Acc=77.32%
# [S3-Epoch 156] Train Loss=0.8687 | Test Loss=0.9641 | Test Acc=77.34%
# [S3-Epoch 157] Train Loss=0.8604 | Test Loss=0.9228 | Test Acc=77.48%
# [S3-Epoch 158] Train Loss=0.6779 | Test Loss=0.8707 | Test Acc=77.98%
# [S3-Epoch 159] Train Loss=0.9327 | Test Loss=0.8951 | Test Acc=77.74%
# [S3-Epoch 160] Train Loss=0.7835 | Test Loss=0.8928 | Test Acc=77.58%
# [S3-Epoch 161] Train Loss=0.9782 | Test Loss=0.9490 | Test Acc=77.42%
# [S3-Epoch 162] Train Loss=0.8374 | Test Loss=0.9120 | Test Acc=77.37%
# [S3-Epoch 163] Train Loss=0.8803 | Test Loss=0.9271 | Test Acc=77.53%
# [S3-Epoch 164] Train Loss=0.7237 | Test Loss=0.9038 | Test Acc=77.30%
# [S3-Epoch 165] Train Loss=0.8385 | Test Loss=0.9233 | Test Acc=77.20%
# [S3-Epoch 166] Train Loss=0.9382 | Test Loss=0.9327 | Test Acc=77.17%
# [S3-Epoch 167] Train Loss=0.9378 | Test Loss=0.8818 | Test Acc=77.60%
# [S3-Epoch 168] Train Loss=0.9541 | Test Loss=0.9277 | Test Acc=77.55%
# [S3-Epoch 169] Train Loss=0.7996 | Test Loss=0.9306 | Test Acc=77.10%
# [S3-Epoch 170] Train Loss=0.9411 | Test Loss=0.9233 | Test Acc=77.44%
# [S3-Epoch 171] Train Loss=0.9079 | Test Loss=0.9076 | Test Acc=77.34%
# [S3-Epoch 172] Train Loss=0.8892 | Test Loss=0.9350 | Test Acc=77.11%
# [S3-Epoch 173] Train Loss=0.8622 | Test Loss=0.9243 | Test Acc=77.55%
# [S3-Epoch 174] Train Loss=0.9371 | Test Loss=0.8887 | Test Acc=77.39%
# [S3-Epoch 175] Train Loss=0.9356 | Test Loss=0.8831 | Test Acc=77.48%
# [S3-Epoch 176] Train Loss=0.7894 | Test Loss=0.8827 | Test Acc=77.48%
# [S3-Epoch 177] Train Loss=0.8127 | Test Loss=0.9374 | Test Acc=77.53%
# [S3-Epoch 178] Train Loss=0.8905 | Test Loss=0.9691 | Test Acc=77.13%
# [S3-Epoch 179] Train Loss=0.8675 | Test Loss=0.8994 | Test Acc=77.32%
# [S3-Epoch 180] Train Loss=1.0081 | Test Loss=0.9806 | Test Acc=77.10%
# [S3-Epoch 181] Train Loss=0.8446 | Test Loss=1.0392 | Test Acc=76.72%
# [S3-Epoch 182] Train Loss=0.8511 | Test Loss=0.9654 | Test Acc=77.24%
# [S3-Epoch 183] Train Loss=0.7764 | Test Loss=0.9612 | Test Acc=77.39%
# [S3-Epoch 184] Train Loss=0.8077 | Test Loss=0.9112 | Test Acc=77.89%
# [S3-Epoch 185] Train Loss=0.7970 | Test Loss=0.9019 | Test Acc=77.56%
# [S3-Epoch 186] Train Loss=0.9117 | Test Loss=0.8891 | Test Acc=78.03%
# [S3-Epoch 187] Train Loss=0.7797 | Test Loss=0.9407 | Test Acc=77.22%
# [S3-Epoch 188] Train Loss=0.8049 | Test Loss=0.9080 | Test Acc=77.53%
# [S3-Epoch 189] Train Loss=0.6413 | Test Loss=0.8924 | Test Acc=77.74%
# [S3-Epoch 190] Train Loss=0.8870 | Test Loss=0.9388 | Test Acc=77.25%
# [S3-Epoch 191] Train Loss=0.8782 | Test Loss=0.8787 | Test Acc=77.68%
# [S3-Epoch 192] Train Loss=0.8669 | Test Loss=0.9337 | Test Acc=77.55%
# [S3-Epoch 193] Train Loss=0.8693 | Test Loss=0.8999 | Test Acc=77.29%
# [S3-Epoch 194] Train Loss=0.9127 | Test Loss=0.9210 | Test Acc=77.91%
# [S3-Epoch 195] Train Loss=0.8657 | Test Loss=0.9896 | Test Acc=77.15%
# [S3-Epoch 196] Train Loss=0.9024 | Test Loss=0.9320 | Test Acc=77.51%
# [S3-Epoch 197] Train Loss=0.9694 | Test Loss=0.9516 | Test Acc=77.17%
# [S3-Epoch 198] Train Loss=0.8204 | Test Loss=0.8832 | Test Acc=77.80%
# [S3-Epoch 199] Train Loss=0.8488 | Test Loss=0.9038 | Test Acc=77.53%
# [S3-Epoch 200] Train Loss=0.8696 | Test Loss=0.9202 | Test Acc=77.48%

# %%
hist.to_csv("StandardCNN_CUB.csv", index=False)
