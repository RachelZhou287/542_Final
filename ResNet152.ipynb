# %%
import os, time, random, gc
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from tqdm import tqdm
import pandas as pd

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATA_ROOT = "data/CUB_200_2011"
NUM_CLASSES = 200
INIT_LR = 1e-4
MID_LR = 1e-5
FINAL_LR = 1e-6
WEIGHT_DECAY = 1e-4
BATCH_SIZE = 32
STEP_SIZE = 7
EPOCHS_STAGE1 = 10
EPOCHS_STAGE2 = 50
EPOCHS_STAGE3 = 250
SEED = 87

torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.5, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.1),
    transforms.RandomRotation(degrees=15),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

class CUBDataset(Dataset):
    def __init__(self, root, train=True, transform=None):
        img_txt = os.path.join(root, "images.txt")
        label_txt = os.path.join(root, "image_class_labels.txt")
        split_txt = os.path.join(root, "train_test_split.txt")

        with open(img_txt) as f:
            imgs = [x.strip().split(" ") for x in f.readlines()]
        with open(label_txt) as f:
            labels = [int(x.strip().split(" ")[1]) - 1 for x in f.readlines()]
        with open(split_txt) as f:
            split = [int(x.strip().split(" ")[1]) for x in f.readlines()]

        self.samples = []
        for (img_id, img_path), label, is_train in zip(imgs, labels, split):
            if (train and is_train == 1) or (not train and is_train == 0):
                self.samples.append((os.path.join(root, "images", img_path), label))
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        img = Image.open(img_path).convert("RGB")
        if self.transform:
            img = self.transform(img)
        return img, label

train_loader = DataLoader(
    CUBDataset(DATA_ROOT, True, train_transforms),
    batch_size=BATCH_SIZE, shuffle=True, num_workers=10,
    pin_memory=True, persistent_workers=True, prefetch_factor=4
)
test_loader = DataLoader(
    CUBDataset(DATA_ROOT, False, test_transforms),
    batch_size=BATCH_SIZE, shuffle=False, num_workers=10,
    pin_memory=True, persistent_workers=True, prefetch_factor=4
)

def mixup_data(x, y, alpha=0.2, device='cuda'):
    lam = np.random.beta(alpha, alpha) if alpha > 0 else 1
    batch_size = x.size()[0]
    index = torch.randperm(batch_size).to(device)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

@torch.no_grad()
def evaluate_model(model, loader, criterion, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    for images, labels in loader:
        images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)
        outputs = model(images)
        loss = criterion(outputs, labels)
        total_loss += loss.item() * labels.size(0)
        correct += (outputs.argmax(1) == labels).sum().item()
        total += labels.size(0)
    return 100 * correct / total, total_loss / total

def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    running_loss, total = 0.0, 0

    for images, labels in loader:
        images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)

        # MixUp
        mixed_imgs, y_a, y_b, lam = mixup_data(images, labels, device=device)

        optimizer.zero_grad()
        outputs = model(mixed_imgs)
        loss = mixup_criterion(criterion, outputs, y_a, y_b, lam)

        # correctly accumulate *sample-level* loss
        running_loss += loss.item() * labels.size(0)
        total += labels.size(0)

        loss.backward()
        optimizer.step()

    return running_loss / total

# %% [markdown]
# # Model: ResNet152

# %%
def get_resnet():
    model = models.resnet152(weights=models.ResNet152_Weights.IMAGENET1K_V1)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, NUM_CLASSES)
    return model

# %%
def run_training_3stage(model_name, model):
    print("=== Training ===")
    criterion = nn.CrossEntropyLoss()

    # ============================================================
    # Stage 1: Train classifier only (linear probing)
    # ============================================================
    for p in model.parameters(): 
        p.requires_grad = False
    for p in model.fc.parameters(): 
        p.requires_grad = True

    print("--- Stage 1 ---")
    optimizer = optim.AdamW(model.fc.parameters(), lr=INIT_LR, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=STEP_SIZE, gamma=0.1)

    stage1_hist = []
    for epoch in range(EPOCHS_STAGE1):
        tr_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
        te_acc, te_loss = evaluate_model(model, test_loader, criterion, DEVICE)
        scheduler.step()

        stage1_hist.append((epoch+1, tr_loss, te_loss, te_acc))

        print(f"[S1-Epoch {epoch+1:02d}] "
              f"Train Loss={tr_loss:.4f} | Test Loss={te_loss:.4f} | Test Acc={te_acc:.2f}%")


    # ============================================================
    # Stage 2: Fine-tune entire network (moderate LR)
    # ============================================================
    for p in model.parameters():
        p.requires_grad = True

    print("--- Stage 2---")
    optimizer = optim.AdamW(model.parameters(), lr=MID_LR, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=EPOCHS_STAGE2, gamma=0.1)

    stage2_hist = []
    best_acc = 0.0

    for epoch in range(EPOCHS_STAGE2):
        tr_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
        te_acc, te_loss = evaluate_model(model, test_loader, criterion, DEVICE)
        scheduler.step()

        stage2_hist.append((epoch+1, tr_loss, te_loss, te_acc))

        if te_acc > best_acc:
            best_acc = te_acc
            torch.save(model.state_dict(), f"best_{model_name}.pt")

        print(f"[S2-Epoch {epoch+1:03d}] "
              f"Train Loss={tr_loss:.4f} | Test Loss={te_loss:.4f} | Test Acc={te_acc:.2f}%")


    # ============================================================
    # Stage 3: Low-LR refinement (very small LR)
    # ============================================================
    print("--- Stage 3---")
    optimizer = optim.AdamW(model.parameters(), lr=FINAL_LR, weight_decay=WEIGHT_DECAY)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=EPOCHS_STAGE3, gamma=0.1)

    stage3_hist = []

    for epoch in range(EPOCHS_STAGE3):
        tr_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
        te_acc, te_loss = evaluate_model(model, test_loader, criterion, DEVICE)
        scheduler.step()

        stage3_hist.append((epoch+1, tr_loss, te_loss, te_acc))

        print(f"[S3-Epoch {epoch+1:03d}] "
              f"Train Loss={tr_loss:.4f} | Test Loss={te_loss:.4f} | Test Acc={te_acc:.2f}%")


    return stage1_hist, stage2_hist, stage3_hist

# %%
gc.collect()
torch.cuda.empty_cache()

results = {}

for name, model_fn in [("ResNet",get_resnet)]:
    model = model_fn().to(DEVICE)
    s1, s2, s3 = run_training_3stage(name, model)
    df1 = pd.DataFrame(s1, columns=["epoch", "train_loss", "test_loss", "test_acc"])
    df1["stage"] = "Stage 1"
    df1["model"] = name
    
    df2 = pd.DataFrame(s2, columns=["epoch", "train_loss", "test_loss", "test_acc"])
    df2["stage"] = "Stage 2"
    df2["model"] = name
    
    df3 = pd.DataFrame(s3, columns=["epoch", "train_loss", "test_loss", "test_acc"])
    df3["stage"] = "Stage 3"
    df3["model"] = name
    hist = pd.concat([df1, df2, df3], ignore_index=True)
# Out:
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.12/multiprocessing/queues.py", line 259, in _feed
#     reader_close()
#   File "/root/miniconda3/lib/python3.12/multiprocessing/connection.py", line 178, in close
#     self._close()
#   File "/root/miniconda3/lib/python3.12/multiprocessing/connection.py", line 377, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# === Training ===
# --- Stage 1 ---
# [S1-Epoch 01] Train Loss=5.2301 | Test Loss=4.9211 | Test Acc=7.47%
# [S1-Epoch 02] Train Loss=4.8781 | Test Loss=4.5642 | Test Acc=16.60%
# [S1-Epoch 03] Train Loss=4.5674 | Test Loss=4.2221 | Test Acc=28.22%
# [S1-Epoch 04] Train Loss=4.3136 | Test Loss=3.9506 | Test Acc=33.02%
# [S1-Epoch 05] Train Loss=4.1176 | Test Loss=3.7169 | Test Acc=35.69%
# [S1-Epoch 06] Train Loss=3.9044 | Test Loss=3.4722 | Test Acc=40.30%
# [S1-Epoch 07] Train Loss=3.8009 | Test Loss=3.3109 | Test Acc=41.80%
# [S1-Epoch 08] Train Loss=3.6076 | Test Loss=3.2835 | Test Acc=45.58%
# [S1-Epoch 09] Train Loss=3.5737 | Test Loss=3.2716 | Test Acc=47.70%
# [S1-Epoch 10] Train Loss=3.5548 | Test Loss=3.2311 | Test Acc=50.29%
# --- Stage 2---
# [S2-Epoch 001] Train Loss=3.0986 | Test Loss=2.2417 | Test Acc=60.03%
# [S2-Epoch 002] Train Loss=2.6874 | Test Loss=1.9290 | Test Acc=64.64%
# [S2-Epoch 003] Train Loss=2.4526 | Test Loss=1.7393 | Test Acc=68.88%
# [S2-Epoch 004] Train Loss=2.2076 | Test Loss=1.5912 | Test Acc=70.90%
# [S2-Epoch 005] Train Loss=2.0621 | Test Loss=1.4625 | Test Acc=72.66%
# [S2-Epoch 006] Train Loss=2.1303 | Test Loss=1.3533 | Test Acc=74.59%
# [S2-Epoch 007] Train Loss=2.0236 | Test Loss=1.2803 | Test Acc=75.15%
# [S2-Epoch 008] Train Loss=1.9000 | Test Loss=1.1948 | Test Acc=76.25%
# [S2-Epoch 009] Train Loss=1.7821 | Test Loss=1.1264 | Test Acc=77.18%
# [S2-Epoch 010] Train Loss=1.6994 | Test Loss=1.1008 | Test Acc=78.03%
# [S2-Epoch 011] Train Loss=1.6338 | Test Loss=1.0485 | Test Acc=78.34%
# [S2-Epoch 012] Train Loss=1.5826 | Test Loss=1.0148 | Test Acc=78.58%
# [S2-Epoch 013] Train Loss=1.4869 | Test Loss=0.9750 | Test Acc=79.13%
# [S2-Epoch 014] Train Loss=1.4177 | Test Loss=0.9087 | Test Acc=80.07%
# [S2-Epoch 015] Train Loss=1.4194 | Test Loss=0.9283 | Test Acc=80.39%
# [S2-Epoch 016] Train Loss=1.3719 | Test Loss=0.8976 | Test Acc=80.46%
# [S2-Epoch 017] Train Loss=1.3771 | Test Loss=0.8660 | Test Acc=80.76%
# [S2-Epoch 018] Train Loss=1.2694 | Test Loss=0.8386 | Test Acc=80.95%
# [S2-Epoch 019] Train Loss=1.3487 | Test Loss=0.8547 | Test Acc=80.86%
# [S2-Epoch 020] Train Loss=1.1473 | Test Loss=0.8018 | Test Acc=81.33%
# [S2-Epoch 021] Train Loss=1.1687 | Test Loss=0.8521 | Test Acc=81.15%
# [S2-Epoch 022] Train Loss=1.1341 | Test Loss=0.8119 | Test Acc=81.45%
# [S2-Epoch 023] Train Loss=1.1744 | Test Loss=0.7792 | Test Acc=81.48%
# [S2-Epoch 024] Train Loss=1.2003 | Test Loss=0.7896 | Test Acc=81.29%
# [S2-Epoch 025] Train Loss=1.2549 | Test Loss=0.7971 | Test Acc=81.20%
# [S2-Epoch 026] Train Loss=0.9312 | Test Loss=0.7780 | Test Acc=81.39%
# [S2-Epoch 027] Train Loss=1.0968 | Test Loss=0.7699 | Test Acc=81.41%
# [S2-Epoch 028] Train Loss=1.0265 | Test Loss=0.7708 | Test Acc=81.67%
# [S2-Epoch 029] Train Loss=1.0168 | Test Loss=0.7722 | Test Acc=82.00%
# [S2-Epoch 030] Train Loss=0.9933 | Test Loss=0.7684 | Test Acc=82.03%
# [S2-Epoch 031] Train Loss=0.9813 | Test Loss=0.7639 | Test Acc=81.95%
# [S2-Epoch 032] Train Loss=0.9498 | Test Loss=0.7659 | Test Acc=81.64%
# [S2-Epoch 033] Train Loss=1.0002 | Test Loss=0.7412 | Test Acc=82.02%
# [S2-Epoch 034] Train Loss=0.9485 | Test Loss=0.7193 | Test Acc=82.15%
# [S2-Epoch 035] Train Loss=0.8691 | Test Loss=0.7426 | Test Acc=81.71%
# [S2-Epoch 036] Train Loss=0.8980 | Test Loss=0.7660 | Test Acc=81.84%
# [S2-Epoch 037] Train Loss=0.8981 | Test Loss=0.7625 | Test Acc=81.62%
# [S2-Epoch 038] Train Loss=0.8557 | Test Loss=0.7452 | Test Acc=81.60%
# [S2-Epoch 039] Train Loss=0.8915 | Test Loss=0.7732 | Test Acc=81.52%
# [S2-Epoch 040] Train Loss=0.9089 | Test Loss=0.7514 | Test Acc=81.84%
# [S2-Epoch 041] Train Loss=1.0069 | Test Loss=0.7745 | Test Acc=81.83%
# [S2-Epoch 042] Train Loss=0.9656 | Test Loss=0.7449 | Test Acc=81.74%
# [S2-Epoch 043] Train Loss=0.8754 | Test Loss=0.7480 | Test Acc=82.00%
# [S2-Epoch 044] Train Loss=0.9407 | Test Loss=0.7474 | Test Acc=82.05%
# [S2-Epoch 045] Train Loss=0.8830 | Test Loss=0.7602 | Test Acc=81.96%
# [S2-Epoch 046] Train Loss=0.9424 | Test Loss=0.7736 | Test Acc=81.58%
# [S2-Epoch 047] Train Loss=0.8524 | Test Loss=0.7672 | Test Acc=81.65%
# [S2-Epoch 048] Train Loss=0.7374 | Test Loss=0.7256 | Test Acc=82.41%
# [S2-Epoch 049] Train Loss=0.7784 | Test Loss=0.7565 | Test Acc=81.93%
# [S2-Epoch 050] Train Loss=0.8994 | Test Loss=0.7891 | Test Acc=81.72%
# --- Stage 3---
# [S3-Epoch 001] Train Loss=0.8485 | Test Loss=0.7475 | Test Acc=82.36%
# [S3-Epoch 002] Train Loss=0.9335 | Test Loss=0.7477 | Test Acc=82.52%
# [S3-Epoch 003] Train Loss=0.8353 | Test Loss=0.7244 | Test Acc=82.59%
# [S3-Epoch 004] Train Loss=0.9184 | Test Loss=0.7462 | Test Acc=82.52%
# [S3-Epoch 005] Train Loss=0.9775 | Test Loss=0.7492 | Test Acc=82.40%
# [S3-Epoch 006] Train Loss=0.9470 | Test Loss=0.7502 | Test Acc=82.26%
# [S3-Epoch 007] Train Loss=0.8211 | Test Loss=0.7401 | Test Acc=82.55%
# [S3-Epoch 008] Train Loss=0.7822 | Test Loss=0.6968 | Test Acc=82.81%
# [S3-Epoch 009] Train Loss=0.6894 | Test Loss=0.7282 | Test Acc=82.62%
# [S3-Epoch 010] Train Loss=0.6276 | Test Loss=0.7238 | Test Acc=82.52%
# [S3-Epoch 011] Train Loss=0.8131 | Test Loss=0.7570 | Test Acc=82.83%
# [S3-Epoch 012] Train Loss=0.8631 | Test Loss=0.7448 | Test Acc=82.60%
# [S3-Epoch 013] Train Loss=0.7989 | Test Loss=0.7243 | Test Acc=82.84%
# [S3-Epoch 014] Train Loss=0.7006 | Test Loss=0.7237 | Test Acc=82.52%
# [S3-Epoch 015] Train Loss=0.6763 | Test Loss=0.7014 | Test Acc=82.86%
# [S3-Epoch 016] Train Loss=0.8730 | Test Loss=0.7158 | Test Acc=83.21%
# [S3-Epoch 017] Train Loss=0.6628 | Test Loss=0.7043 | Test Acc=83.00%
# [S3-Epoch 018] Train Loss=0.7510 | Test Loss=0.7342 | Test Acc=82.83%
# [S3-Epoch 019] Train Loss=0.6985 | Test Loss=0.7147 | Test Acc=82.79%
# [S3-Epoch 020] Train Loss=0.8373 | Test Loss=0.7148 | Test Acc=82.57%
# [S3-Epoch 021] Train Loss=0.7628 | Test Loss=0.7265 | Test Acc=83.10%
# [S3-Epoch 022] Train Loss=0.8660 | Test Loss=0.7307 | Test Acc=82.91%
# [S3-Epoch 023] Train Loss=0.7208 | Test Loss=0.7314 | Test Acc=82.95%
# [S3-Epoch 024] Train Loss=0.8428 | Test Loss=0.7219 | Test Acc=82.71%
# [S3-Epoch 025] Train Loss=0.7953 | Test Loss=0.7639 | Test Acc=82.76%
# [S3-Epoch 026] Train Loss=0.7469 | Test Loss=0.7085 | Test Acc=82.76%
# [S3-Epoch 027] Train Loss=0.7926 | Test Loss=0.7455 | Test Acc=82.95%
# [S3-Epoch 028] Train Loss=0.9231 | Test Loss=0.7135 | Test Acc=82.98%
# [S3-Epoch 029] Train Loss=0.7954 | Test Loss=0.7801 | Test Acc=82.50%
# [S3-Epoch 030] Train Loss=0.8510 | Test Loss=0.7155 | Test Acc=82.65%
# [S3-Epoch 031] Train Loss=0.7958 | Test Loss=0.7553 | Test Acc=82.76%
# [S3-Epoch 032] Train Loss=0.8624 | Test Loss=0.7200 | Test Acc=82.84%
# [S3-Epoch 033] Train Loss=0.7335 | Test Loss=0.7135 | Test Acc=82.84%
# [S3-Epoch 034] Train Loss=0.8570 | Test Loss=0.7931 | Test Acc=82.93%
# [S3-Epoch 035] Train Loss=0.7870 | Test Loss=0.7499 | Test Acc=82.65%
# [S3-Epoch 036] Train Loss=0.8741 | Test Loss=0.7325 | Test Acc=82.76%
# [S3-Epoch 037] Train Loss=0.7403 | Test Loss=0.7066 | Test Acc=82.95%
# [S3-Epoch 038] Train Loss=0.7682 | Test Loss=0.7405 | Test Acc=82.84%
# [S3-Epoch 039] Train Loss=0.8250 | Test Loss=0.7380 | Test Acc=82.52%
# [S3-Epoch 040] Train Loss=0.7923 | Test Loss=0.7201 | Test Acc=82.78%
# [S3-Epoch 041] Train Loss=0.8253 | Test Loss=0.6963 | Test Acc=83.05%
# [S3-Epoch 042] Train Loss=0.7775 | Test Loss=0.7114 | Test Acc=82.88%
# [S3-Epoch 043] Train Loss=0.7751 | Test Loss=0.7318 | Test Acc=82.98%
# [S3-Epoch 044] Train Loss=0.7557 | Test Loss=0.7353 | Test Acc=82.86%
# [S3-Epoch 045] Train Loss=0.7431 | Test Loss=0.7212 | Test Acc=82.79%
# [S3-Epoch 046] Train Loss=0.7807 | Test Loss=0.7310 | Test Acc=82.79%
# [S3-Epoch 047] Train Loss=0.7695 | Test Loss=0.7042 | Test Acc=82.84%
# [S3-Epoch 048] Train Loss=0.7909 | Test Loss=0.7402 | Test Acc=82.93%
# [S3-Epoch 049] Train Loss=0.8258 | Test Loss=0.7010 | Test Acc=82.83%
# [S3-Epoch 050] Train Loss=0.8141 | Test Loss=0.7196 | Test Acc=82.67%
# [S3-Epoch 051] Train Loss=0.9418 | Test Loss=0.7465 | Test Acc=82.67%
# [S3-Epoch 052] Train Loss=0.8234 | Test Loss=0.7045 | Test Acc=82.50%
# [S3-Epoch 053] Train Loss=0.7049 | Test Loss=0.7362 | Test Acc=82.65%
# [S3-Epoch 054] Train Loss=0.7244 | Test Loss=0.7266 | Test Acc=82.88%
# [S3-Epoch 055] Train Loss=0.7607 | Test Loss=0.7402 | Test Acc=82.55%
# [S3-Epoch 056] Train Loss=0.7255 | Test Loss=0.7178 | Test Acc=82.93%
# [S3-Epoch 057] Train Loss=0.8626 | Test Loss=0.7353 | Test Acc=82.72%
# [S3-Epoch 058] Train Loss=0.8654 | Test Loss=0.7306 | Test Acc=83.00%
# [S3-Epoch 059] Train Loss=0.7608 | Test Loss=0.7206 | Test Acc=83.12%
# [S3-Epoch 060] Train Loss=0.7395 | Test Loss=0.7294 | Test Acc=82.79%
# [S3-Epoch 061] Train Loss=0.6980 | Test Loss=0.7162 | Test Acc=82.65%
# [S3-Epoch 062] Train Loss=0.7483 | Test Loss=0.6937 | Test Acc=82.62%
# [S3-Epoch 063] Train Loss=0.7072 | Test Loss=0.7136 | Test Acc=82.78%
# [S3-Epoch 064] Train Loss=0.8040 | Test Loss=0.7133 | Test Acc=82.55%
# [S3-Epoch 065] Train Loss=0.7710 | Test Loss=0.7273 | Test Acc=82.81%
# [S3-Epoch 066] Train Loss=0.8430 | Test Loss=0.7250 | Test Acc=82.43%
# [S3-Epoch 067] Train Loss=0.6311 | Test Loss=0.7223 | Test Acc=82.88%
# [S3-Epoch 068] Train Loss=0.8196 | Test Loss=0.7345 | Test Acc=82.72%
# [S3-Epoch 069] Train Loss=0.7779 | Test Loss=0.7330 | Test Acc=82.50%
# [S3-Epoch 070] Train Loss=0.7541 | Test Loss=0.7094 | Test Acc=82.79%
# [S3-Epoch 071] Train Loss=0.7713 | Test Loss=0.7286 | Test Acc=82.81%
# [S3-Epoch 072] Train Loss=0.8295 | Test Loss=0.7138 | Test Acc=83.03%
# [S3-Epoch 073] Train Loss=0.8245 | Test Loss=0.7188 | Test Acc=82.74%
# [S3-Epoch 074] Train Loss=0.8213 | Test Loss=0.7242 | Test Acc=82.60%
# [S3-Epoch 075] Train Loss=0.8600 | Test Loss=0.7537 | Test Acc=82.65%
# [S3-Epoch 076] Train Loss=0.7859 | Test Loss=0.7249 | Test Acc=82.81%
# [S3-Epoch 077] Train Loss=0.7648 | Test Loss=0.7361 | Test Acc=82.55%
# [S3-Epoch 078] Train Loss=0.7510 | Test Loss=0.6959 | Test Acc=82.93%
# [S3-Epoch 079] Train Loss=0.6324 | Test Loss=0.7145 | Test Acc=82.79%
# [S3-Epoch 080] Train Loss=0.7511 | Test Loss=0.7360 | Test Acc=82.91%
# [S3-Epoch 081] Train Loss=0.7602 | Test Loss=0.7713 | Test Acc=82.76%
# [S3-Epoch 082] Train Loss=0.8109 | Test Loss=0.7191 | Test Acc=82.83%
# [S3-Epoch 083] Train Loss=0.8043 | Test Loss=0.7215 | Test Acc=82.78%
# [S3-Epoch 084] Train Loss=0.7964 | Test Loss=0.7516 | Test Acc=82.76%
# [S3-Epoch 085] Train Loss=0.7865 | Test Loss=0.7876 | Test Acc=82.48%
# [S3-Epoch 086] Train Loss=0.6925 | Test Loss=0.6993 | Test Acc=82.78%
# [S3-Epoch 087] Train Loss=0.8428 | Test Loss=0.7239 | Test Acc=82.81%
# [S3-Epoch 088] Train Loss=0.7654 | Test Loss=0.7687 | Test Acc=82.86%
# [S3-Epoch 089] Train Loss=0.5929 | Test Loss=0.7027 | Test Acc=82.90%
# [S3-Epoch 090] Train Loss=0.7136 | Test Loss=0.7082 | Test Acc=82.88%
# [S3-Epoch 091] Train Loss=0.7917 | Test Loss=0.7142 | Test Acc=82.97%
# [S3-Epoch 092] Train Loss=0.7392 | Test Loss=0.7275 | Test Acc=82.83%
# [S3-Epoch 093] Train Loss=0.7096 | Test Loss=0.7193 | Test Acc=82.95%
# [S3-Epoch 094] Train Loss=0.8768 | Test Loss=0.7311 | Test Acc=82.90%
# [S3-Epoch 095] Train Loss=0.6929 | Test Loss=0.7241 | Test Acc=82.95%
# [S3-Epoch 096] Train Loss=0.7485 | Test Loss=0.7303 | Test Acc=82.97%
# [S3-Epoch 097] Train Loss=0.7552 | Test Loss=0.7394 | Test Acc=82.45%
# [S3-Epoch 098] Train Loss=0.7753 | Test Loss=0.6903 | Test Acc=82.98%
# [S3-Epoch 099] Train Loss=0.8493 | Test Loss=0.7040 | Test Acc=82.90%
# [S3-Epoch 100] Train Loss=0.8497 | Test Loss=0.6949 | Test Acc=82.84%
# [S3-Epoch 101] Train Loss=0.6417 | Test Loss=0.7201 | Test Acc=82.81%
# [S3-Epoch 102] Train Loss=0.7365 | Test Loss=0.7101 | Test Acc=82.98%
# [S3-Epoch 103] Train Loss=0.7730 | Test Loss=0.7196 | Test Acc=82.97%
# [S3-Epoch 104] Train Loss=0.7904 | Test Loss=0.7114 | Test Acc=82.97%
# [S3-Epoch 105] Train Loss=0.8478 | Test Loss=0.7424 | Test Acc=82.95%
# [S3-Epoch 106] Train Loss=0.7015 | Test Loss=0.6946 | Test Acc=82.97%
# [S3-Epoch 107] Train Loss=0.7101 | Test Loss=0.6973 | Test Acc=83.14%
# [S3-Epoch 108] Train Loss=0.7777 | Test Loss=0.7507 | Test Acc=82.69%
# [S3-Epoch 109] Train Loss=0.7762 | Test Loss=0.7374 | Test Acc=82.65%
# [S3-Epoch 110] Train Loss=0.6719 | Test Loss=0.7098 | Test Acc=83.03%
# [S3-Epoch 111] Train Loss=0.6791 | Test Loss=0.7272 | Test Acc=82.67%
# [S3-Epoch 112] Train Loss=0.7638 | Test Loss=0.7285 | Test Acc=82.91%
# [S3-Epoch 113] Train Loss=0.7072 | Test Loss=0.6983 | Test Acc=83.02%
# [S3-Epoch 114] Train Loss=0.8120 | Test Loss=0.7197 | Test Acc=83.05%
# [S3-Epoch 115] Train Loss=0.7230 | Test Loss=0.6986 | Test Acc=83.07%
# [S3-Epoch 116] Train Loss=0.7865 | Test Loss=0.7510 | Test Acc=82.79%
# [S3-Epoch 117] Train Loss=0.7503 | Test Loss=0.7204 | Test Acc=83.02%
# [S3-Epoch 118] Train Loss=0.7256 | Test Loss=0.7301 | Test Acc=83.21%
# [S3-Epoch 119] Train Loss=0.7528 | Test Loss=0.7116 | Test Acc=83.12%
# [S3-Epoch 120] Train Loss=0.7321 | Test Loss=0.7030 | Test Acc=82.86%
# [S3-Epoch 121] Train Loss=0.6591 | Test Loss=0.7094 | Test Acc=82.97%
# [S3-Epoch 122] Train Loss=0.8761 | Test Loss=0.7117 | Test Acc=83.10%
# [S3-Epoch 123] Train Loss=0.8973 | Test Loss=0.7421 | Test Acc=82.57%
# [S3-Epoch 124] Train Loss=0.6770 | Test Loss=0.7251 | Test Acc=83.17%
# [S3-Epoch 125] Train Loss=0.8757 | Test Loss=0.7311 | Test Acc=83.03%
# [S3-Epoch 126] Train Loss=0.7562 | Test Loss=0.7405 | Test Acc=82.86%
# [S3-Epoch 127] Train Loss=0.7896 | Test Loss=0.7276 | Test Acc=82.78%
# [S3-Epoch 128] Train Loss=0.7954 | Test Loss=0.7394 | Test Acc=83.05%
# [S3-Epoch 129] Train Loss=0.8502 | Test Loss=0.7194 | Test Acc=82.83%
# [S3-Epoch 130] Train Loss=0.8741 | Test Loss=0.7104 | Test Acc=82.74%
# [S3-Epoch 131] Train Loss=0.7763 | Test Loss=0.7133 | Test Acc=82.91%
# [S3-Epoch 132] Train Loss=0.7904 | Test Loss=0.7206 | Test Acc=82.93%
# [S3-Epoch 133] Train Loss=0.8020 | Test Loss=0.7294 | Test Acc=82.97%
# [S3-Epoch 134] Train Loss=0.7465 | Test Loss=0.7147 | Test Acc=82.86%
# [S3-Epoch 135] Train Loss=0.7601 | Test Loss=0.7264 | Test Acc=82.79%
# [S3-Epoch 136] Train Loss=0.7700 | Test Loss=0.7150 | Test Acc=83.03%
# [S3-Epoch 137] Train Loss=0.7988 | Test Loss=0.7390 | Test Acc=82.62%
# [S3-Epoch 138] Train Loss=0.8318 | Test Loss=0.7197 | Test Acc=82.86%
# [S3-Epoch 139] Train Loss=0.7853 | Test Loss=0.7147 | Test Acc=83.03%
# [S3-Epoch 140] Train Loss=0.6487 | Test Loss=0.7361 | Test Acc=82.81%
# [S3-Epoch 141] Train Loss=0.8321 | Test Loss=0.7208 | Test Acc=82.88%
# [S3-Epoch 142] Train Loss=0.7456 | Test Loss=0.7240 | Test Acc=82.59%
# [S3-Epoch 143] Train Loss=0.6023 | Test Loss=0.7164 | Test Acc=82.97%
# [S3-Epoch 144] Train Loss=0.7490 | Test Loss=0.7123 | Test Acc=82.72%
# [S3-Epoch 145] Train Loss=0.7641 | Test Loss=0.7023 | Test Acc=82.98%
# [S3-Epoch 146] Train Loss=0.7444 | Test Loss=0.7159 | Test Acc=83.10%
# [S3-Epoch 147] Train Loss=0.7379 | Test Loss=0.7762 | Test Acc=82.76%
# [S3-Epoch 148] Train Loss=0.7548 | Test Loss=0.7049 | Test Acc=83.14%
# [S3-Epoch 149] Train Loss=0.7913 | Test Loss=0.7239 | Test Acc=82.98%
# [S3-Epoch 150] Train Loss=0.7347 | Test Loss=0.6976 | Test Acc=83.14%
# [S3-Epoch 151] Train Loss=0.7873 | Test Loss=0.7431 | Test Acc=82.83%
# [S3-Epoch 152] Train Loss=0.7592 | Test Loss=0.7375 | Test Acc=82.79%
# [S3-Epoch 153] Train Loss=0.8074 | Test Loss=0.7387 | Test Acc=82.84%
# [S3-Epoch 154] Train Loss=0.7129 | Test Loss=0.6862 | Test Acc=83.12%
# [S3-Epoch 155] Train Loss=0.7267 | Test Loss=0.7053 | Test Acc=83.22%
# [S3-Epoch 156] Train Loss=0.7843 | Test Loss=0.7100 | Test Acc=82.95%
# [S3-Epoch 157] Train Loss=0.8059 | Test Loss=0.7117 | Test Acc=82.71%
# [S3-Epoch 158] Train Loss=0.8182 | Test Loss=0.7267 | Test Acc=82.71%
# [S3-Epoch 159] Train Loss=0.7799 | Test Loss=0.7396 | Test Acc=82.74%
# [S3-Epoch 160] Train Loss=0.6129 | Test Loss=0.7024 | Test Acc=83.02%
# [S3-Epoch 161] Train Loss=0.8514 | Test Loss=0.7342 | Test Acc=82.84%
# [S3-Epoch 162] Train Loss=0.8596 | Test Loss=0.7358 | Test Acc=82.86%
# [S3-Epoch 163] Train Loss=0.7323 | Test Loss=0.7308 | Test Acc=82.90%
# [S3-Epoch 164] Train Loss=0.7510 | Test Loss=0.7418 | Test Acc=82.91%
# [S3-Epoch 165] Train Loss=0.7851 | Test Loss=0.7322 | Test Acc=82.97%
# [S3-Epoch 166] Train Loss=0.8529 | Test Loss=0.7241 | Test Acc=82.71%
# [S3-Epoch 167] Train Loss=0.7706 | Test Loss=0.7046 | Test Acc=82.84%
# [S3-Epoch 168] Train Loss=0.7876 | Test Loss=0.7425 | Test Acc=82.84%
# [S3-Epoch 169] Train Loss=0.8271 | Test Loss=0.7214 | Test Acc=83.24%
# [S3-Epoch 170] Train Loss=0.8272 | Test Loss=0.7035 | Test Acc=83.00%
# [S3-Epoch 171] Train Loss=0.7566 | Test Loss=0.7170 | Test Acc=82.97%
# [S3-Epoch 172] Train Loss=0.7754 | Test Loss=0.7565 | Test Acc=82.74%
# [S3-Epoch 173] Train Loss=0.7453 | Test Loss=0.7299 | Test Acc=82.84%
# [S3-Epoch 174] Train Loss=0.8354 | Test Loss=0.7070 | Test Acc=82.83%
# [S3-Epoch 175] Train Loss=0.6769 | Test Loss=0.7111 | Test Acc=82.72%
# [S3-Epoch 176] Train Loss=0.6555 | Test Loss=0.7025 | Test Acc=82.86%
# [S3-Epoch 177] Train Loss=0.7658 | Test Loss=0.7054 | Test Acc=82.81%
# [S3-Epoch 178] Train Loss=0.6800 | Test Loss=0.7116 | Test Acc=83.02%
# [S3-Epoch 179] Train Loss=0.7246 | Test Loss=0.7094 | Test Acc=82.83%
# [S3-Epoch 180] Train Loss=0.7655 | Test Loss=0.7429 | Test Acc=82.72%
# [S3-Epoch 181] Train Loss=0.6428 | Test Loss=0.6987 | Test Acc=82.53%
# [S3-Epoch 182] Train Loss=0.7155 | Test Loss=0.7062 | Test Acc=83.00%
# [S3-Epoch 183] Train Loss=0.8369 | Test Loss=0.6977 | Test Acc=83.09%
# [S3-Epoch 184] Train Loss=0.8597 | Test Loss=0.7300 | Test Acc=82.67%
# [S3-Epoch 185] Train Loss=0.7355 | Test Loss=0.7018 | Test Acc=83.03%
# [S3-Epoch 186] Train Loss=0.7470 | Test Loss=0.7382 | Test Acc=82.86%
# [S3-Epoch 187] Train Loss=0.7022 | Test Loss=0.7080 | Test Acc=82.86%
# [S3-Epoch 188] Train Loss=0.7522 | Test Loss=0.7172 | Test Acc=82.84%
# [S3-Epoch 189] Train Loss=0.7976 | Test Loss=0.7279 | Test Acc=82.55%
# [S3-Epoch 190] Train Loss=0.7269 | Test Loss=0.6987 | Test Acc=82.74%
# [S3-Epoch 191] Train Loss=0.7537 | Test Loss=0.7193 | Test Acc=82.91%
# [S3-Epoch 192] Train Loss=0.7522 | Test Loss=0.7141 | Test Acc=82.57%
# [S3-Epoch 193] Train Loss=0.7807 | Test Loss=0.7309 | Test Acc=82.76%
# [S3-Epoch 194] Train Loss=0.7806 | Test Loss=0.7116 | Test Acc=82.91%
# [S3-Epoch 195] Train Loss=0.7941 | Test Loss=0.6992 | Test Acc=82.78%
# [S3-Epoch 196] Train Loss=0.7448 | Test Loss=0.7203 | Test Acc=83.19%
# [S3-Epoch 197] Train Loss=0.8341 | Test Loss=0.7152 | Test Acc=82.79%
# [S3-Epoch 198] Train Loss=0.8349 | Test Loss=0.7376 | Test Acc=82.88%
# [S3-Epoch 199] Train Loss=0.7186 | Test Loss=0.7145 | Test Acc=82.86%
# [S3-Epoch 200] Train Loss=0.8186 | Test Loss=0.7071 | Test Acc=82.67%
# [S3-Epoch 201] Train Loss=0.8106 | Test Loss=0.7207 | Test Acc=82.55%
# [S3-Epoch 202] Train Loss=0.8085 | Test Loss=0.7137 | Test Acc=82.74%
# [S3-Epoch 203] Train Loss=0.8147 | Test Loss=0.7027 | Test Acc=82.69%
# [S3-Epoch 204] Train Loss=0.7684 | Test Loss=0.7024 | Test Acc=82.86%
# [S3-Epoch 205] Train Loss=0.8108 | Test Loss=0.7059 | Test Acc=83.03%
# [S3-Epoch 206] Train Loss=0.7578 | Test Loss=0.7222 | Test Acc=82.88%
# [S3-Epoch 207] Train Loss=0.7333 | Test Loss=0.7171 | Test Acc=82.72%
# [S3-Epoch 208] Train Loss=0.5950 | Test Loss=0.6852 | Test Acc=82.71%
# [S3-Epoch 209] Train Loss=0.8319 | Test Loss=0.6853 | Test Acc=82.88%
# [S3-Epoch 210] Train Loss=0.6870 | Test Loss=0.7022 | Test Acc=82.69%
# [S3-Epoch 211] Train Loss=0.8435 | Test Loss=0.7069 | Test Acc=82.52%
# [S3-Epoch 212] Train Loss=0.7437 | Test Loss=0.7065 | Test Acc=82.83%
# [S3-Epoch 213] Train Loss=0.7562 | Test Loss=0.7222 | Test Acc=82.78%
# [S3-Epoch 214] Train Loss=0.6341 | Test Loss=0.7097 | Test Acc=82.65%
# [S3-Epoch 215] Train Loss=0.7266 | Test Loss=0.7090 | Test Acc=82.97%
# [S3-Epoch 216] Train Loss=0.8183 | Test Loss=0.7188 | Test Acc=82.50%
# [S3-Epoch 217] Train Loss=0.8125 | Test Loss=0.6925 | Test Acc=82.69%
# [S3-Epoch 218] Train Loss=0.8246 | Test Loss=0.7179 | Test Acc=82.59%
# [S3-Epoch 219] Train Loss=0.6935 | Test Loss=0.7378 | Test Acc=82.65%
# [S3-Epoch 220] Train Loss=0.8098 | Test Loss=0.7084 | Test Acc=82.83%
# [S3-Epoch 221] Train Loss=0.7866 | Test Loss=0.7020 | Test Acc=82.78%
# [S3-Epoch 222] Train Loss=0.7733 | Test Loss=0.7311 | Test Acc=82.72%
# [S3-Epoch 223] Train Loss=0.7567 | Test Loss=0.7088 | Test Acc=82.59%
# [S3-Epoch 224] Train Loss=0.8100 | Test Loss=0.6943 | Test Acc=82.98%
# [S3-Epoch 225] Train Loss=0.8132 | Test Loss=0.7067 | Test Acc=82.59%
# [S3-Epoch 226] Train Loss=0.6793 | Test Loss=0.7059 | Test Acc=82.88%
# [S3-Epoch 227] Train Loss=0.6919 | Test Loss=0.7181 | Test Acc=82.62%
# [S3-Epoch 228] Train Loss=0.7697 | Test Loss=0.7856 | Test Acc=82.34%
# [S3-Epoch 229] Train Loss=0.7398 | Test Loss=0.7176 | Test Acc=82.69%
# [S3-Epoch 230] Train Loss=0.8781 | Test Loss=0.7657 | Test Acc=82.43%
# [S3-Epoch 231] Train Loss=0.7262 | Test Loss=0.7925 | Test Acc=82.55%
# [S3-Epoch 232] Train Loss=0.7407 | Test Loss=0.7425 | Test Acc=82.60%
# [S3-Epoch 233] Train Loss=0.6711 | Test Loss=0.7358 | Test Acc=82.57%
# [S3-Epoch 234] Train Loss=0.6896 | Test Loss=0.7133 | Test Acc=82.83%
# [S3-Epoch 235] Train Loss=0.6859 | Test Loss=0.7090 | Test Acc=82.76%
# [S3-Epoch 236] Train Loss=0.7893 | Test Loss=0.6998 | Test Acc=82.74%
# [S3-Epoch 237] Train Loss=0.6806 | Test Loss=0.7201 | Test Acc=82.76%
# [S3-Epoch 238] Train Loss=0.6940 | Test Loss=0.7086 | Test Acc=82.83%
# [S3-Epoch 239] Train Loss=0.5480 | Test Loss=0.7069 | Test Acc=82.95%
# [S3-Epoch 240] Train Loss=0.7747 | Test Loss=0.7274 | Test Acc=82.55%
# [S3-Epoch 241] Train Loss=0.7536 | Test Loss=0.6903 | Test Acc=82.81%
# [S3-Epoch 242] Train Loss=0.7340 | Test Loss=0.7294 | Test Acc=82.76%
# [S3-Epoch 243] Train Loss=0.7592 | Test Loss=0.7214 | Test Acc=82.57%
# [S3-Epoch 244] Train Loss=0.7807 | Test Loss=0.7245 | Test Acc=82.83%
# [S3-Epoch 245] Train Loss=0.7437 | Test Loss=0.7698 | Test Acc=82.53%
# [S3-Epoch 246] Train Loss=0.7645 | Test Loss=0.7212 | Test Acc=82.53%
# [S3-Epoch 247] Train Loss=0.8429 | Test Loss=0.7410 | Test Acc=82.57%
# [S3-Epoch 248] Train Loss=0.7199 | Test Loss=0.6920 | Test Acc=82.72%
# [S3-Epoch 249] Train Loss=0.7447 | Test Loss=0.7130 | Test Acc=82.86%
# [S3-Epoch 250] Train Loss=0.7561 | Test Loss=0.7316 | Test Acc=82.74%

# %%
hist.to_csv("ResNet_3stg.csv", index=False)
